# %% [markdown]
# # tabpfn_xgboost_mskf.ipynb
# ## 実験条件
# * 学習時にgreeks.csvのEpsilon使用, テストデータでは訓練データのEpsilonの最大値+1とする
# * 欠損値は中央値で補完
# * greeks.csvのAlphaを予測、予測後にA->0, (B, G, D)->1に変換
# * CVはMultilabelStratifiedKFoldで、Beta, Gamma, Deltaのクラス割合が同じになるように分割
# ### 結果
# * CV: 0.19097697170787517
# ## 変更点(2023-08-05 20:59)
# * XGBClassifierのsample_weightを設定
# * sample_weightを計算するためにAlphaをラベルエンコーディング
# ### 結果
# * CV: 0.18313566432976108

# %% [markdown]
# ## TabPFNのインストール
# ### 事前にダウンロードするファイル:
# * TabPFN: <https://www.kaggle.com/datasets/carlmcbrideellis/tabpfn-019-whl>
# * MultilabelStratifiedKFold: <https://www.kaggle.com/datasets/tilii7/iterative-stratification-017>

# %%
# KaggleNotebookではコメントアウトを外す
# !pip install -q /kaggle/input/tabpfn-019-whl/tabpfn-0.1.9-py3-none-any.whl
# !mkdir /opt/conda/lib/python3.10/site-packages/tabpfn/models_diff
# !cp /kaggle/input/tabpfn-019-whl/prior_diff_real_checkpoint_n_0_epoch_100.cpkt /opt/conda/lib/python3.10/site-packages/tabpfn/models_diff/
# !pip install -q /kaggle/input/iterative-stratification-017/iterative_stratification-0.1.7-py3-none-any.whl

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import log_loss
import matplotlib.pyplot as plt
# model
from sklearn.base import BaseEstimator
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.utils.class_weight import compute_sample_weight
import lightgbm as lgb
from tabpfn import TabPFNClassifier
# over/under sampling
from imblearn.over_sampling import SMOTE # SMOTE
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
# Imputation
from sklearn.impute import SimpleImputer
from sklearn.impute import KNNImputer
from sklearn.feature_selection import SelectKBest, f_classif# Feature Selection
import category_encoders as encoders
from sklearn.preprocessing import LabelEncoder, RobustScaler
# cross validation
from sklearn.model_selection import StratifiedKFold
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold
# others
from datetime import date, datetime
from sklearn.preprocessing import LabelEncoder
import optuna
import warnings
warnings.simplefilter('ignore')

# 環境を指定
env = 'local'
# env = 'kaggle'

# %% [markdown]
# ## データの読み込み

# %%
# ディレクトリの指定
if env == 'local':
    BASE_DIR = '../../data'
elif env == 'kaggle':
    BASE_DIR = '/kaggle/input/icr-identify-age-related-conditions/'
else:
    raise ValueError("Invalid environment. Set env as 'local' or 'kaggle'.")

# データの読み込み
train_df = pd.read_csv(f'{BASE_DIR}/train.csv')
# train_df = pd.read_csv(f'{BASE_DIR}/train_integerized.csv')
greeks_df = pd.read_csv(f'{BASE_DIR}/greeks.csv')
test_df = pd.read_csv(f'{BASE_DIR}/test.csv')
submission_df = pd.read_csv(f'{BASE_DIR}/sample_submission.csv')

# greeksと結合
train_df = pd.merge(train_df, greeks_df[['Id', 'Alpha', 'Epsilon']], on='Id', how='left')

# %% [markdown]
# greeksのAはClass0に、B, G, DはClass1に相当

# %%
greeks_df.Alpha.value_counts()
# Out:
# Alpha
# A    509
# B     61
# G     29
# D     18
# Name: count, dtype: int64

# %% [markdown]
# ## Epsilonを特徴量に追加

# %%
# 欠損値以外の日付をグレゴリオ暦の序数形式（1年1月1日を1とし、1日ずつ増やしていく）に変換
train_df.Epsilon[train_df.Epsilon != 'Unknown'] = train_df.Epsilon[train_df.Epsilon != 'Unknown']\
                                        .map(lambda x: datetime.strptime(x, '%m/%d/%Y').toordinal())
# 欠損値をnp.nanに変換
train_df.Epsilon[train_df.Epsilon == 'Unknown'] = np.nan

# 訓練データを説明変数と目的変数に分割
X_train = train_df.drop(['Id', 'EJ', 'Alpha', 'Class'], axis=1)
y_train = train_df[['Class', 'Alpha']]

# テストデータから数値データ以外を削除
X_test = test_df.drop(['Id', 'EJ'], axis=1)

# テストデータは訓練データの最大値+1とする
X_test['Epsilon'] = train_df.Epsilon.max()+1

# %% [markdown]
# ## Alphaをラベルエンコーディング

# %%
from sklearn.preprocessing import LabelEncoder
# ラベルエンコーダを初期化
le = LabelEncoder()
# yを数値に変換
y_train['Alpha'] = le.fit_transform(y_train['Alpha'])

# %% [markdown]
# self.models = [XGBClassifier(eta=0.01267942116017827,
#                              gamma=0.0035099486546295838,
#                              max_depth=10,
#                              min_child_weight=0.00295968493319233,
#                              max_delta_step=3.207138802851332e-05,
#                              subsample=0.17568276820923612,
#                              reg_lambda=76.82036507955048,
#                              reg_alpha=812.280448836668,
#                              n_estimators=100,
#                              learning_rate=0.2,
#                              colsample_bytree=0.85),

# %% [markdown]
# ## モデル、評価基準

# %%
class WeightedEns(BaseEstimator):
    def __init__(self):
        self.models = [
                       XGBClassifier(n_estimators=100,max_depth=3,learning_rate=0.2,subsample=0.9,colsample_bytree=0.85),
                       # TabPFNClassifier(N_ensemble_configurations=256,device='cuda:0')
                      ]
        self.imputer = SimpleImputer(missing_values=np.nan, strategy='median')
        # self.imputer = KNNImputer(n_neighbors=50)
    
    def fit(self, X, y, weights=None):
        classes, y = np.unique(y, return_inverse=True)
        self.classes_ = classes
        X = self.imputer.fit_transform(X)
        for i, model in enumerate(self.models):
            if isinstance(model, XGBClassifier):
                model.fit(X, y, sample_weight=weights) # 決定木ではweightを考慮する
            else:
                model.fit(X,y)
    def set_params(self, params):
        self.models[0].set_params(**params)
    
    def predict_proba(self, X):
        X = self.imputer.transform(X)
        ps = np.stack([model.predict_proba(X) for model in self.models])
        p = np.mean(ps,axis=0)
        class_0_est_instances = p[:,0].sum()
        others_est_instances = p[:,1:].sum()
        # we reweight the probs, since the loss is also balanced like this
        # our models out of the box optimize CE
        # with these changes they optimize balanced CE
        new_p = p * np.array([[1/(class_0_est_instances if i==0 else others_est_instances) for i in range(p.shape[1])]])
        new_p = new_p / np.sum(new_p,axis=1,keepdims=1)
        return np.concatenate((new_p[:,:1],np.sum(new_p[:,1:],1,keepdims=True)), 1)

# 評価基準
def balanced_log_loss(y_true, y_pred):
    N = len(y_true)

    # Nc is the number of observations
    N_1 = np.sum(y_true == 1, axis=0)
    N_0 = np.sum(y_true == 0, axis=0)

    # In order to avoid the extremes of the log function, each predicted probability 𝑝 is replaced with max(min(𝑝,1−10−15),10−15)
    y_pred = np.maximum(np.minimum(y_pred, 1 - 1e-15), 1e-15)

    # balanced logarithmic loss
    loss_numerator = - (1/N_0) * np.sum((1 - y_true) * np.log(1-y_pred)) - (1/N_1) * np.sum(y_true * np.log(y_pred))

    return loss_numerator / 2

# %% [markdown]
# ## Optuna

# %%
# 初期値
seed = 779292
folds = 10
labels = greeks_df[['Beta', 'Gamma', 'Delta']] # クロスバリデーションの分割で考慮する特徴量

def objective(trial):
    # 各分割ごとのバリデーションスコアを格納
    scores = 0
    # クロスバリデーションの分割数を指定
    mskf = MultilabelStratifiedKFold(n_splits=folds, shuffle=True, random_state=seed)
    
    # ハイパーパラメータのサーチ空間を定義
    params = {
        'n_estimators': 100,
        'learning_rate': 0.2,
        'max_depth': trial.suggest_int('max_depth', 10, 20),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 50),
        'gamma': trial.suggest_float('gamma', 0, 1),
        'lambda': trial.suggest_float('lambda', 1e-5, 1.0, log=True),
        'alpha': trial.suggest_float('alpha', 1e-5, 1.0, log=True)
    }

    for fold, (train_index, valid_index) in enumerate(mskf.split(X_train, labels)):
        # 訓練データを分割
        X_train_fold = X_train.iloc[train_index]
        y_train_fold = y_train['Alpha'].iloc[train_index]
        X_valid_fold = X_train.iloc[valid_index]
        y_valid_fold = y_train['Class'].iloc[valid_index]
    
        # Alphaのラベルに重みづけをする
        sample_weights = compute_sample_weight(class_weight='balanced', y=y_train_fold)
        model = WeightedEns()
        model.set_params(params)
        model.fit(X_train_fold, y_train_fold, weights=sample_weights)
        valid_preds = model.predict_proba(X_valid_fold)[:, 1]
        val_score = balanced_log_loss(y_valid_fold, valid_preds)
        scores += val_score

    cv_score = scores / folds
    return cv_score

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=1000)

best_params = study.best_params
print(f'Best parameters: {best_params}')
# Out:
# [I 2023-08-06 23:51:28,054] A new study created in memory with name: no-name-7979bcc2-9489-4a1a-9a27-1c65548fd2b5
# [I 2023-08-06 23:51:29,289] Trial 0 finished with value: 0.26177463899754655 and parameters: {'max_depth': 15, 'subsample': 0.6711446001746522, 'colsample_bytree': 0.7631265478895534, 'min_child_weight': 1, 'gamma': 0.8348372569231347, 'lambda': 1.0433568973294579e-05, 'alpha': 0.8717712304747285}. Best is trial 0 with value: 0.26177463899754655.
# [I 2023-08-06 23:51:30,016] Trial 1 finished with value: 0.25711078502590257 and parameters: {'max_depth': 10, 'subsample': 0.5126948223029311, 'colsample_bytree': 0.6823664018187763, 'min_child_weight': 7, 'gamma': 0.8982501821871622, 'lambda': 3.2703765084741954e-05, 'alpha': 2.657848395181412e-05}. Best is trial 1 with value: 0.25711078502590257.
# [I 2023-08-06 23:51:30,684] Trial 2 finished with value: 0.22893004423755065 and parameters: {'max_depth': 15, 'subsample': 0.5406215070528055, 'colsample_bytree': 0.9012967447121446, 'min_child_weight': 6, 'gamma': 0.36721677318786794, 'lambda': 0.8401861302244843, 'alpha': 0.00015478468598862917}. Best is trial 2 with value: 0.22893004423755065.
# [I 2023-08-06 23:51:31,253] Trial 3 finished with value: 0.3274537361005556 and parameters: {'max_depth': 20, 'subsample': 0.8011034811977266, 'colsample_bytree': 0.693705998452509, 'min_child_weight': 34, 'gamma': 0.6039684982860749, 'lambda': 0.003429569446745855, 'alpha': 0.009676740954654267}. Best is trial 2 with value: 0.22893004423755065.
# [I 2023-08-06 23:51:31,803] Trial 4 finished with value: 0.34193956584148943 and parameters: {'max_depth': 16, 'subsample': 0.982056825682107, 'colsample_bytree': 0.9165215911875104, 'min_child_weight': 44, 'gamma': 0.929931162256633, 'lambda': 0.00014457811944216042, 'alpha': 0.22163375246206307}. Best is trial 2 with value: 0.22893004423755065.
# [I 2023-08-06 23:51:32,343] Trial 5 finished with value: 0.3044166764201721 and parameters: {'max_depth': 19, 'subsample': 0.9937820866090656, 'colsample_bytree': 0.8759753022605778, 'min_child_weight': 30, 'gamma': 0.38092925268148603, 'lambda': 1.8099855602913142e-05, 'alpha': 0.009403052391393819}. Best is trial 2 with value: 0.22893004423755065.
# [I 2023-08-06 23:51:32,802] Trial 6 finished with value: 0.4203971464935686 and parameters: {'max_depth': 12, 'subsample': 0.5501763181394741, 'colsample_bytree': 0.9291866182929877, 'min_child_weight': 43, 'gamma': 0.5694698269572616, 'lambda': 0.0014506989267900631, 'alpha': 0.036706324249693285}. Best is trial 2 with value: 0.22893004423755065.
# [I 2023-08-06 23:51:33,393] Trial 7 finished with value: 0.2776724550769284 and parameters: {'max_depth': 17, 'subsample': 0.7523435362853288, 'colsample_bytree': 0.6637974016625416, 'min_child_weight': 16, 'gamma': 0.8238915737598902, 'lambda': 0.04742107252400413, 'alpha': 0.14703875715459458}. Best is trial 2 with value: 0.22893004423755065.
# [I 2023-08-06 23:51:34,195] Trial 8 finished with value: 0.22125000799587874 and parameters: {'max_depth': 14, 'subsample': 0.7339260289868017, 'colsample_bytree': 0.7368316818114433, 'min_child_weight': 5, 'gamma': 0.14700427900665614, 'lambda': 0.24836326335839723, 'alpha': 0.10851338350192208}. Best is trial 8 with value: 0.22125000799587874.
# [I 2023-08-06 23:51:34,921] Trial 9 finished with value: 0.2557820111416398 and parameters: {'max_depth': 13, 'subsample': 0.772185655011544, 'colsample_bytree': 0.9780190702304856, 'min_child_weight': 11, 'gamma': 0.040312961853618545, 'lambda': 0.004674587853079216, 'alpha': 0.8479883312181105}. Best is trial 8 with value: 0.22125000799587874.
# [I 2023-08-06 23:51:35,477] Trial 10 finished with value: 0.2934737337935541 and parameters: {'max_depth': 13, 'subsample': 0.6587644654091613, 'colsample_bytree': 0.6094448172387549, 'min_child_weight': 20, 'gamma': 0.02076061326542586, 'lambda': 0.7367858317128896, 'alpha': 0.001214043802093402}. Best is trial 8 with value: 0.22125000799587874.
# [I 2023-08-06 23:51:36,199] Trial 11 finished with value: 0.2044492048286874 and parameters: {'max_depth': 14, 'subsample': 0.5988836115198491, 'colsample_bytree': 0.8103357598591646, 'min_child_weight': 3, 'gamma': 0.2603923227416236, 'lambda': 0.8150569401359787, 'alpha': 0.0005156479304754538}. Best is trial 11 with value: 0.2044492048286874.
# [I 2023-08-06 23:51:37,116] Trial 12 finished with value: 0.2063027907556767 and parameters: {'max_depth': 11, 'subsample': 0.6690359188448869, 'colsample_bytree': 0.7901083122420157, 'min_child_weight': 2, 'gamma': 0.17288949888765356, 'lambda': 0.07523757475651507, 'alpha': 0.0011443589916967588}. Best is trial 11 with value: 0.2044492048286874.
# [I 2023-08-06 23:51:37,842] Trial 13 finished with value: 0.28008167448782106 and parameters: {'max_depth': 10, 'subsample': 0.6222881718746309, 'colsample_bytree': 0.8151659086623777, 'min_child_weight': 16, 'gamma': 0.23169265952052032, 'lambda': 0.08495055912575052, 'alpha': 0.0008346462237682539}. Best is trial 11 with value: 0.2044492048286874.
# [I 2023-08-06 23:51:39,301] Trial 14 finished with value: 0.2096828304133175 and parameters: {'max_depth': 11, 'subsample': 0.5998213759752185, 'colsample_bytree': 0.8259292934048642, 'min_child_weight': 1, 'gamma': 0.21790539471963952, 'lambda': 0.060878087153228753, 'alpha': 0.0004088616780690625}. Best is trial 11 with value: 0.2044492048286874.
# [I 2023-08-06 23:51:40,056] Trial 15 finished with value: 0.29492032062533047 and parameters: {'max_depth': 12, 'subsample': 0.5872073081593385, 'colsample_bytree': 0.7776495624703772, 'min_child_weight': 20, 'gamma': 0.34686303858133216, 'lambda': 0.22169909635439264, 'alpha': 9.887890722295335e-05}. Best is trial 11 with value: 0.2044492048286874.
# [I 2023-08-06 23:51:40,869] Trial 16 finished with value: 0.27245280589354176 and parameters: {'max_depth': 17, 'subsample': 0.5057330703520744, 'colsample_bytree': 0.834782936592186, 'min_child_weight': 12, 'gamma': 0.15223670669690667, 'lambda': 0.011887999638631234, 'alpha': 0.002397341171714496}. Best is trial 11 with value: 0.2044492048286874.
# [I 2023-08-06 23:51:41,504] Trial 17 finished with value: 0.31469191147059944 and parameters: {'max_depth': 13, 'subsample': 0.6904310016923491, 'colsample_bytree': 0.8473500104234674, 'min_child_weight': 26, 'gamma': 0.4666964885934744, 'lambda': 0.02148887119620655, 'alpha': 0.004973762571914092}. Best is trial 11 with value: 0.2044492048286874.
# [I 2023-08-06 23:51:42,136] Trial 18 finished with value: 0.37635039253411884 and parameters: {'max_depth': 11, 'subsample': 0.6050967855342757, 'colsample_bytree': 0.7864909199680951, 'min_child_weight': 36, 'gamma': 0.2834027551040767, 'lambda': 0.26116469798910497, 'alpha': 0.0003618326980501205}. Best is trial 11 with value: 0.2044492048286874.
# [I 2023-08-06 23:51:43,024] Trial 19 finished with value: 0.25099223783536245 and parameters: {'max_depth': 14, 'subsample': 0.7020194110859094, 'colsample_bytree': 0.7372278032537307, 'min_child_weight': 10, 'gamma': 0.10866957299173685, 'lambda': 0.97717002113376, 'alpha': 1.9922451393444805e-05}. Best is trial 11 with value: 0.2044492048286874.
# [I 2023-08-06 23:51:44,406] Trial 20 finished with value: 0.1983884570959517 and parameters: {'max_depth': 18, 'subsample': 0.6435484316975786, 'colsample_bytree': 0.8630490219999509, 'min_child_weight': 1, 'gamma': 0.26918520484909636, 'lambda': 0.13601668012456508, 'alpha': 0.0021620884814136593}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:51:45,542] Trial 21 finished with value: 0.20073911210624873 and parameters: {'max_depth': 18, 'subsample': 0.6461936898846107, 'colsample_bytree': 0.8570313312622314, 'min_child_weight': 2, 'gamma': 0.2557895443731148, 'lambda': 0.14222276853345242, 'alpha': 0.0024094029906049728}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:51:46,414] Trial 22 finished with value: 0.23233159436200249 and parameters: {'max_depth': 18, 'subsample': 0.6361402816329349, 'colsample_bytree': 0.860378222088438, 'min_child_weight': 6, 'gamma': 0.28740071572038906, 'lambda': 0.38866496418406976, 'alpha': 0.002983110946169229}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:51:47,191] Trial 23 finished with value: 0.2704276777214209 and parameters: {'max_depth': 20, 'subsample': 0.5913497575546212, 'colsample_bytree': 0.867473694378611, 'min_child_weight': 13, 'gamma': 0.28368174672648394, 'lambda': 0.1238692089624588, 'alpha': 0.00568463927963046}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:51:48,014] Trial 24 finished with value: 0.24247685173351283 and parameters: {'max_depth': 18, 'subsample': 0.5653980628396356, 'colsample_bytree': 0.811615823141513, 'min_child_weight': 8, 'gamma': 0.09495369793849257, 'lambda': 0.16460179514001413, 'alpha': 0.002409250014183893}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:51:49,037] Trial 25 finished with value: 0.22171082412404766 and parameters: {'max_depth': 16, 'subsample': 0.6348244887015418, 'colsample_bytree': 0.8908956524099373, 'min_child_weight': 4, 'gamma': 0.41367490133694196, 'lambda': 0.4333250920964324, 'alpha': 0.01595649097478006}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:51:49,779] Trial 26 finished with value: 0.28605510075872653 and parameters: {'max_depth': 19, 'subsample': 0.5611842801365228, 'colsample_bytree': 0.8354080686442064, 'min_child_weight': 16, 'gamma': 0.23115529559239573, 'lambda': 0.030275140479069103, 'alpha': 0.000493030422985111}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:51:51,287] Trial 27 finished with value: 0.21986643280754886 and parameters: {'max_depth': 17, 'subsample': 0.7113139944214695, 'colsample_bytree': 0.8507005911591046, 'min_child_weight': 1, 'gamma': 0.4997167354581683, 'lambda': 0.1399467959475343, 'alpha': 0.0015537008470512229}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:51:51,994] Trial 28 finished with value: 0.30234685278156853 and parameters: {'max_depth': 16, 'subsample': 0.6453204290365763, 'colsample_bytree': 0.9409730280015413, 'min_child_weight': 22, 'gamma': 0.0670716048046393, 'lambda': 0.3593888391131739, 'alpha': 0.00015131764010269878}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:51:53,055] Trial 29 finished with value: 0.21593374737754897 and parameters: {'max_depth': 18, 'subsample': 0.6725808127892974, 'colsample_bytree': 0.8814931123127566, 'min_child_weight': 3, 'gamma': 0.311881226012574, 'lambda': 0.030706504224161737, 'alpha': 0.003996901375171716}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:51:53,871] Trial 30 finished with value: 0.25294526891842023 and parameters: {'max_depth': 19, 'subsample': 0.6218537627356797, 'colsample_bytree': 0.7971491546691022, 'min_child_weight': 9, 'gamma': 0.017315352206448503, 'lambda': 0.5083618166831336, 'alpha': 0.000691019999625875}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:51:54,995] Trial 31 finished with value: 0.19947150143910766 and parameters: {'max_depth': 14, 'subsample': 0.6788898884589133, 'colsample_bytree': 0.8064590449657454, 'min_child_weight': 2, 'gamma': 0.16323489200552443, 'lambda': 0.08949520921130934, 'alpha': 0.0017775042209792278}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:51:56,295] Trial 32 finished with value: 0.1998240426835573 and parameters: {'max_depth': 14, 'subsample': 0.6732244691717044, 'colsample_bytree': 0.8148879567342673, 'min_child_weight': 1, 'gamma': 0.19436782781883755, 'lambda': 0.1206696910684851, 'alpha': 0.001512235012971948}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:51:57,229] Trial 33 finished with value: 0.22827955792212382 and parameters: {'max_depth': 15, 'subsample': 0.6850077258839127, 'colsample_bytree': 0.7632253862764757, 'min_child_weight': 7, 'gamma': 0.18004443777320553, 'lambda': 0.09669977947780907, 'alpha': 0.0013338322365796602}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:51:58,171] Trial 34 finished with value: 0.22087828676132487 and parameters: {'max_depth': 15, 'subsample': 0.72326905796248, 'colsample_bytree': 0.859309353724476, 'min_child_weight': 6, 'gamma': 0.11458069343497773, 'lambda': 0.15234100822359176, 'alpha': 0.0026436999700418756}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:51:58,814] Trial 35 finished with value: 0.4099958326774217 and parameters: {'max_depth': 16, 'subsample': 0.652677856736894, 'colsample_bytree': 0.9040394505196372, 'min_child_weight': 49, 'gamma': 0.19264249510753434, 'lambda': 0.05004921866932365, 'alpha': 0.007796941327718998}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:52:00,378] Trial 36 finished with value: 0.2160479294813416 and parameters: {'max_depth': 14, 'subsample': 0.6940030356404183, 'colsample_bytree': 0.8339797343717782, 'min_child_weight': 1, 'gamma': 0.32551888567325615, 'lambda': 0.015543608580712623, 'alpha': 0.01418633273672254}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:52:01,145] Trial 37 finished with value: 0.28350379262710956 and parameters: {'max_depth': 15, 'subsample': 0.5250094255484846, 'colsample_bytree': 0.8819750361418479, 'min_child_weight': 14, 'gamma': 0.39830453787542175, 'lambda': 0.22199138041636715, 'alpha': 0.0002776174117310273}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:52:02,040] Trial 38 finished with value: 0.23190670694330145 and parameters: {'max_depth': 20, 'subsample': 0.8004462478571167, 'colsample_bytree': 0.8107957924081244, 'min_child_weight': 9, 'gamma': 0.07509972971575521, 'lambda': 0.009555950828557395, 'alpha': 0.0017796645802419374}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:52:03,095] Trial 39 finished with value: 0.20964238641405405 and parameters: {'max_depth': 17, 'subsample': 0.7393746483537667, 'colsample_bytree': 0.9038693481101286, 'min_child_weight': 5, 'gamma': 0.2201701624611285, 'lambda': 0.04167199360908448, 'alpha': 0.003935512776866419}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:52:04,090] Trial 40 finished with value: 0.21665240563068727 and parameters: {'max_depth': 13, 'subsample': 0.6716738399077204, 'colsample_bytree': 0.8524965042473484, 'min_child_weight': 4, 'gamma': 0.1381123997271624, 'lambda': 0.08763665016434176, 'alpha': 0.023084360573390337}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:52:05,153] Trial 41 finished with value: 0.21332541273958666 and parameters: {'max_depth': 14, 'subsample': 0.6167761942540514, 'colsample_bytree': 0.8056967150604452, 'min_child_weight': 3, 'gamma': 0.2604699173637951, 'lambda': 0.670634655249428, 'alpha': 0.0007026634141317365}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:52:06,580] Trial 42 finished with value: 0.20902677117406188 and parameters: {'max_depth': 14, 'subsample': 0.6532157836012892, 'colsample_bytree': 0.8237741580531358, 'min_child_weight': 1, 'gamma': 0.3315942246688136, 'lambda': 0.9486621141116012, 'alpha': 0.006555896118056533}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:52:07,513] Trial 43 finished with value: 0.21947446313754643 and parameters: {'max_depth': 12, 'subsample': 0.5840338580701713, 'colsample_bytree': 0.7738297179034067, 'min_child_weight': 4, 'gamma': 0.24965033026977387, 'lambda': 0.4201302482686145, 'alpha': 0.0017604533285696434}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:52:08,338] Trial 44 finished with value: 0.2335445945202827 and parameters: {'max_depth': 16, 'subsample': 0.7099391673517179, 'colsample_bytree': 0.7986487764797014, 'min_child_weight': 8, 'gamma': 0.1975413154350097, 'lambda': 0.24197588627716385, 'alpha': 0.0011277744456750056}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:52:09,014] Trial 45 finished with value: 0.35530457603525034 and parameters: {'max_depth': 14, 'subsample': 0.6231913721867903, 'colsample_bytree': 0.8723804339192812, 'min_child_weight': 32, 'gamma': 0.1564518001576772, 'lambda': 0.07948356804267974, 'alpha': 0.0007925591464202545}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:52:09,983] Trial 46 finished with value: 0.22626239467684145 and parameters: {'max_depth': 15, 'subsample': 0.6587844000608286, 'colsample_bytree': 0.7514424719609245, 'min_child_weight': 6, 'gamma': 0.3636726889667577, 'lambda': 0.6494791811614921, 'alpha': 5.483250344493722e-05}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:52:10,825] Trial 47 finished with value: 0.2563754054004052 and parameters: {'max_depth': 13, 'subsample': 0.5399745729677053, 'colsample_bytree': 0.825437169779739, 'min_child_weight': 11, 'gamma': 0.2506502236443349, 'lambda': 0.14628135686534463, 'alpha': 0.0002519226315287584}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:52:11,437] Trial 48 finished with value: 0.34890801119909287 and parameters: {'max_depth': 18, 'subsample': 0.7599366988022435, 'colsample_bytree': 0.8447939168982103, 'min_child_weight': 37, 'gamma': 0.05529190649742344, 'lambda': 0.04964504735522911, 'alpha': 0.0004904985671996241}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:52:12,514] Trial 49 finished with value: 0.20686794321807467 and parameters: {'max_depth': 13, 'subsample': 0.6811113898420231, 'colsample_bytree': 0.7849343917514634, 'min_child_weight': 2, 'gamma': 0.0044358456152813475, 'lambda': 0.35315166280984084, 'alpha': 0.0033775551675762055}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:52:13,519] Trial 50 finished with value: 0.21222941252516375 and parameters: {'max_depth': 12, 'subsample': 0.7260426344100485, 'colsample_bytree': 0.8170658795173579, 'min_child_weight': 3, 'gamma': 0.13885698316788844, 'lambda': 0.06453330799106523, 'alpha': 0.0019008946228303504}. Best is trial 20 with value: 0.1983884570959517.
# [I 2023-08-06 23:52:14,765] Trial 51 finished with value: 0.19688225830696843 and parameters: {'max_depth': 11, 'subsample': 0.6613223665723112, 'colsample_bytree': 0.7951224866464328, 'min_child_weight': 1, 'gamma': 0.17413341268882904, 'lambda': 0.09741365264961138, 'alpha': 0.0011904734523057754}. Best is trial 51 with value: 0.19688225830696843.
# [I 2023-08-06 23:52:16,021] Trial 52 finished with value: 0.21012997708534747 and parameters: {'max_depth': 19, 'subsample': 0.6459703578932362, 'colsample_bytree': 0.7717694922997149, 'min_child_weight': 1, 'gamma': 0.18256233113184397, 'lambda': 0.11343913551254949, 'alpha': 0.0009644796120267638}. Best is trial 51 with value: 0.19688225830696843.
# [I 2023-08-06 23:52:16,951] Trial 53 finished with value: 0.2290779922413638 and parameters: {'max_depth': 10, 'subsample': 0.6082590006048758, 'colsample_bytree': 0.8057722165831652, 'min_child_weight': 5, 'gamma': 0.21147960217231057, 'lambda': 0.234921099258566, 'alpha': 0.004980384673753443}. Best is trial 51 with value: 0.19688225830696843.
# [I 2023-08-06 23:52:17,792] Trial 54 finished with value: 0.24324879827309545 and parameters: {'max_depth': 12, 'subsample': 0.630672297749133, 'colsample_bytree': 0.793726277944812, 'min_child_weight': 7, 'gamma': 0.11333253679663513, 'lambda': 0.6570546375850564, 'alpha': 0.0011687807621560602}. Best is trial 51 with value: 0.19688225830696843.
# [I 2023-08-06 23:52:18,795] Trial 55 finished with value: 0.1997551572720433 and parameters: {'max_depth': 11, 'subsample': 0.6654463324717045, 'colsample_bytree': 0.8339887650436443, 'min_child_weight': 3, 'gamma': 0.3009889560249759, 'lambda': 0.1724958075214289, 'alpha': 0.0005855241528117223}. Best is trial 51 with value: 0.19688225830696843.
# [I 2023-08-06 23:52:19,876] Trial 56 finished with value: 0.2003213626456545 and parameters: {'max_depth': 11, 'subsample': 0.6685760309452132, 'colsample_bytree': 0.8387092255466471, 'min_child_weight': 3, 'gamma': 0.2905273824049896, 'lambda': 0.07309047709915911, 'alpha': 0.0026834336244253992}. Best is trial 51 with value: 0.19688225830696843.
# [I 2023-08-06 23:52:20,755] Trial 57 finished with value: 0.24873624333736863 and parameters: {'max_depth': 11, 'subsample': 0.6980471526819232, 'colsample_bytree': 0.8328859291208935, 'min_child_weight': 10, 'gamma': 0.29832588137838756, 'lambda': 0.02547103475753677, 'alpha': 0.009418125094875763}. Best is trial 51 with value: 0.19688225830696843.
# [I 2023-08-06 23:52:21,774] Trial 58 finished with value: 0.21645573210705082 and parameters: {'max_depth': 10, 'subsample': 0.6754039527963736, 'colsample_bytree': 0.8683912803541884, 'min_child_weight': 5, 'gamma': 0.389106758393093, 'lambda': 0.06788566062925931, 'alpha': 0.0030526410849248085}. Best is trial 51 with value: 0.19688225830696843.
# [I 2023-08-06 23:52:22,596] Trial 59 finished with value: 0.2401752844688431 and parameters: {'max_depth': 11, 'subsample': 0.6692180189338766, 'colsample_bytree': 0.8374372751026011, 'min_child_weight': 8, 'gamma': 0.34550363518722804, 'lambda': 0.037813190501946536, 'alpha': 0.0006784297791724914}. Best is trial 51 with value: 0.19688225830696843.
# [I 2023-08-06 23:52:23,374] Trial 60 finished with value: 0.26334396199156507 and parameters: {'max_depth': 10, 'subsample': 0.7108616342743289, 'colsample_bytree': 0.8202853551546179, 'min_child_weight': 14, 'gamma': 0.16554931435528109, 'lambda': 0.10101829902316892, 'alpha': 0.001578154986941492}. Best is trial 51 with value: 0.19688225830696843.
# [I 2023-08-06 23:52:24,392] Trial 61 finished with value: 0.19450725926633186 and parameters: {'max_depth': 11, 'subsample': 0.6495551572695765, 'colsample_bytree': 0.8550111142926052, 'min_child_weight': 2, 'gamma': 0.26321760305728614, 'lambda': 0.15617275100015673, 'alpha': 0.002364728871697766}. Best is trial 61 with value: 0.19450725926633186.
# [I 2023-08-06 23:52:25,397] Trial 62 finished with value: 0.21443515845887137 and parameters: {'max_depth': 11, 'subsample': 0.6904445043705916, 'colsample_bytree': 0.8481738977693997, 'min_child_weight': 3, 'gamma': 0.21817615021750886, 'lambda': 0.18676051541644287, 'alpha': 0.0010106821265944282}. Best is trial 61 with value: 0.19450725926633186.
# [I 2023-08-06 23:52:26,831] Trial 63 finished with value: 0.19758031093354655 and parameters: {'max_depth': 12, 'subsample': 0.662258696964295, 'colsample_bytree': 0.7884470600933657, 'min_child_weight': 1, 'gamma': 0.28698696098878074, 'lambda': 0.2970043119592357, 'alpha': 0.00229264213510764}. Best is trial 61 with value: 0.19450725926633186.
# [I 2023-08-06 23:52:28,073] Trial 64 finished with value: 0.21445148720736046 and parameters: {'max_depth': 12, 'subsample': 0.632150644782404, 'colsample_bytree': 0.7849256623345904, 'min_child_weight': 1, 'gamma': 0.2551794851752722, 'lambda': 0.3138245496562365, 'alpha': 0.004609286594015551}. Best is trial 61 with value: 0.19450725926633186.
# [I 2023-08-06 23:52:28,696] Trial 65 finished with value: 0.316036870584005 and parameters: {'max_depth': 12, 'subsample': 0.6419739663554854, 'colsample_bytree': 0.7988671611685181, 'min_child_weight': 25, 'gamma': 0.3107299001190167, 'lambda': 0.19655947714685448, 'alpha': 0.002003541897122091}. Best is trial 61 with value: 0.19450725926633186.
# [I 2023-08-06 23:52:29,546] Trial 66 finished with value: 0.23205022828119998 and parameters: {'max_depth': 11, 'subsample': 0.6107324582791077, 'colsample_bytree': 0.7611593833737769, 'min_child_weight': 5, 'gamma': 0.19824583101103765, 'lambda': 0.31396198238422807, 'alpha': 0.0005627774975454905}. Best is trial 61 with value: 0.19450725926633186.
# [I 2023-08-06 23:52:30,313] Trial 67 finished with value: 0.23394424419988646 and parameters: {'max_depth': 10, 'subsample': 0.6620858107658729, 'colsample_bytree': 0.8192858446630542, 'min_child_weight': 7, 'gamma': 0.44188771248723274, 'lambda': 0.1278595982942384, 'alpha': 0.001476621400431786}. Best is trial 61 with value: 0.19450725926633186.
# [I 2023-08-06 23:52:31,207] Trial 68 finished with value: 0.198731256590827 and parameters: {'max_depth': 11, 'subsample': 0.68590864138987, 'colsample_bytree': 0.7843400224803336, 'min_child_weight': 2, 'gamma': 0.08872923374533145, 'lambda': 0.46557899693766697, 'alpha': 0.0003743800048648657}. Best is trial 61 with value: 0.19450725926633186.
# [I 2023-08-06 23:52:32,231] Trial 69 finished with value: 0.22021349548816938 and parameters: {'max_depth': 10, 'subsample': 0.6852928158999361, 'colsample_bytree': 0.7283123964095405, 'min_child_weight': 4, 'gamma': 0.03726155306909579, 'lambda': 0.4912206502929987, 'alpha': 0.0003517022768355043}. Best is trial 61 with value: 0.19450725926633186.
# [I 2023-08-06 23:52:33,244] Trial 70 finished with value: 0.20015209099775158 and parameters: {'max_depth': 11, 'subsample': 0.7000913834214147, 'colsample_bytree': 0.7905879164743068, 'min_child_weight': 2, 'gamma': 0.09718479703613547, 'lambda': 0.3030359768314018, 'alpha': 0.000927996905080978}. Best is trial 61 with value: 0.19450725926633186.
# [I 2023-08-06 23:52:34,450] Trial 71 finished with value: 0.19723721474567987 and parameters: {'max_depth': 12, 'subsample': 0.6575640466499362, 'colsample_bytree': 0.8119085044908132, 'min_child_weight': 1, 'gamma': 0.22543070742262192, 'lambda': 0.18724052791654208, 'alpha': 0.0021626157515770837}. Best is trial 61 with value: 0.19450725926633186.
# [I 2023-08-06 23:52:35,466] Trial 72 finished with value: 0.19287575690634629 and parameters: {'max_depth': 12, 'subsample': 0.6550389236039368, 'colsample_bytree': 0.8039597997979726, 'min_child_weight': 2, 'gamma': 0.15256318199854385, 'lambda': 0.18161455111026564, 'alpha': 0.002335930027235905}. Best is trial 72 with value: 0.19287575690634629.
# [I 2023-08-06 23:52:36,244] Trial 73 finished with value: 0.23589855100578436 and parameters: {'max_depth': 12, 'subsample': 0.6382376716939714, 'colsample_bytree': 0.7788364045274928, 'min_child_weight': 6, 'gamma': 0.1303333274298779, 'lambda': 0.47477657641723625, 'alpha': 0.0029962802251160734}. Best is trial 72 with value: 0.19287575690634629.
# [I 2023-08-06 23:52:37,272] Trial 74 finished with value: 0.20065284623035642 and parameters: {'max_depth': 13, 'subsample': 0.6517461821549149, 'colsample_bytree': 0.8050098916029371, 'min_child_weight': 1, 'gamma': 0.1649997768960982, 'lambda': 0.19328854305816817, 'alpha': 0.006307433542692236}. Best is trial 72 with value: 0.19287575690634629.
# [I 2023-08-06 23:52:37,793] Trial 75 finished with value: 0.3844789465329857 and parameters: {'max_depth': 12, 'subsample': 0.626435669813677, 'colsample_bytree': 0.7905647800789523, 'min_child_weight': 41, 'gamma': 0.08245694646582433, 'lambda': 0.2736685776236008, 'alpha': 0.0039867114797518255}. Best is trial 72 with value: 0.19287575690634629.
# [I 2023-08-06 23:52:38,616] Trial 76 finished with value: 0.21894276339774832 and parameters: {'max_depth': 12, 'subsample': 0.689964154159342, 'colsample_bytree': 0.8588110723477599, 'min_child_weight': 4, 'gamma': 0.23201455236735855, 'lambda': 0.10033783527928654, 'alpha': 0.002142160742552601}. Best is trial 72 with value: 0.19287575690634629.
# [I 2023-08-06 23:52:39,517] Trial 77 finished with value: 0.1975033499087817 and parameters: {'max_depth': 13, 'subsample': 0.6578580132663303, 'colsample_bytree': 0.810707864971114, 'min_child_weight': 2, 'gamma': 0.11995263481642982, 'lambda': 0.05263448036753745, 'alpha': 0.001246815097376377}. Best is trial 72 with value: 0.19287575690634629.
# [I 2023-08-06 23:52:40,106] Trial 78 finished with value: 0.2859987031662182 and parameters: {'max_depth': 11, 'subsample': 0.5962896985523579, 'colsample_bytree': 0.8252363363322159, 'min_child_weight': 18, 'gamma': 0.12756247602538007, 'lambda': 0.05371111496480125, 'alpha': 0.0009276074868691476}. Best is trial 72 with value: 0.19287575690634629.
# [I 2023-08-06 23:52:40,882] Trial 79 finished with value: 0.25030298067858076 and parameters: {'max_depth': 12, 'subsample': 0.6548314452363844, 'colsample_bytree': 0.7687889832228217, 'min_child_weight': 9, 'gamma': 0.04606137700527402, 'lambda': 0.5892961125733011, 'alpha': 0.0012089777009839267}. Best is trial 72 with value: 0.19287575690634629.
# [I 2023-08-06 23:52:41,675] Trial 80 finished with value: 0.22519016654368898 and parameters: {'max_depth': 13, 'subsample': 0.6196265165405586, 'colsample_bytree': 0.7998325303639587, 'min_child_weight': 5, 'gamma': 0.10546175892873064, 'lambda': 0.998486094065534, 'alpha': 0.002210559791471643}. Best is trial 72 with value: 0.19287575690634629.
# [I 2023-08-06 23:52:42,590] Trial 81 finished with value: 0.20611061139866807 and parameters: {'max_depth': 13, 'subsample': 0.6425799574216574, 'colsample_bytree': 0.8103412499032275, 'min_child_weight': 2, 'gamma': 0.15090986654441774, 'lambda': 0.14828304180456953, 'alpha': 0.0032283528437272242}. Best is trial 72 with value: 0.19287575690634629.
# [I 2023-08-06 23:52:43,541] Trial 82 finished with value: 0.19741225768769036 and parameters: {'max_depth': 13, 'subsample': 0.6555907655866419, 'colsample_bytree': 0.7778472556174982, 'min_child_weight': 2, 'gamma': 0.17292532220692433, 'lambda': 0.09475714684159843, 'alpha': 0.001325591428826574}. Best is trial 72 with value: 0.19287575690634629.
# [I 2023-08-06 23:52:44,356] Trial 83 finished with value: 0.2057076447288327 and parameters: {'max_depth': 13, 'subsample': 0.6616199802585494, 'colsample_bytree': 0.7544876790420082, 'min_child_weight': 4, 'gamma': 0.07016252737651602, 'lambda': 0.23226863285842714, 'alpha': 0.0012599749334000427}. Best is trial 72 with value: 0.19287575690634629.
# [I 2023-08-06 23:52:45,321] Trial 84 finished with value: 0.20543729433201632 and parameters: {'max_depth': 12, 'subsample': 0.631896515733132, 'colsample_bytree': 0.7781797430043672, 'min_child_weight': 2, 'gamma': 0.1753564171304009, 'lambda': 0.3682780693129278, 'alpha': 0.005029125328366727}. Best is trial 72 with value: 0.19287575690634629.
# [I 2023-08-06 23:52:46,140] Trial 85 finished with value: 0.23618178853647645 and parameters: {'max_depth': 11, 'subsample': 0.6835900738050217, 'colsample_bytree': 0.783620282907858, 'min_child_weight': 7, 'gamma': 0.27262108360831855, 'lambda': 0.06211259110892279, 'alpha': 0.000839902804613777}. Best is trial 72 with value: 0.19287575690634629.
# [I 2023-08-06 23:52:47,183] Trial 86 finished with value: 0.20834551973647888 and parameters: {'max_depth': 11, 'subsample': 0.6103729472356498, 'colsample_bytree': 0.7932762662358036, 'min_child_weight': 1, 'gamma': 0.096224580787444, 'lambda': 0.16242389679934693, 'alpha': 0.0024121761305588812}. Best is trial 72 with value: 0.19287575690634629.
# [I 2023-08-06 23:52:47,921] Trial 87 finished with value: 0.22435362140739076 and parameters: {'max_depth': 12, 'subsample': 0.6545669809712074, 'colsample_bytree': 0.8144779131616265, 'min_child_weight': 6, 'gamma': 0.24029818088042315, 'lambda': 0.10341216765295833, 'alpha': 0.00042917691633043896}. Best is trial 72 with value: 0.19287575690634629.
# [I 2023-08-06 23:52:48,786] Trial 88 finished with value: 0.20682931439180025 and parameters: {'max_depth': 13, 'subsample': 0.7068932402430181, 'colsample_bytree': 0.846658794464013, 'min_child_weight': 3, 'gamma': 0.19269856498177437, 'lambda': 0.04264043051308315, 'alpha': 0.0014742231642938886}. Best is trial 72 with value: 0.19287575690634629.
# [I 2023-08-06 23:52:49,718] Trial 89 finished with value: 0.21240474434989598 and parameters: {'max_depth': 12, 'subsample': 0.6413704678353662, 'colsample_bytree': 0.8285084893537584, 'min_child_weight': 2, 'gamma': 0.27233093592207125, 'lambda': 0.39544110745145006, 'alpha': 0.0007211577251246127}. Best is trial 72 with value: 0.19287575690634629.
# [I 2023-08-06 23:52:50,596] Trial 90 finished with value: 0.21539946865127613 and parameters: {'max_depth': 11, 'subsample': 0.6760643310328776, 'colsample_bytree': 0.7756554836406998, 'min_child_weight': 4, 'gamma': 0.22804420600647884, 'lambda': 0.11803938479925938, 'alpha': 0.003742716151486074}. Best is trial 72 with value: 0.19287575690634629.
# [I 2023-08-06 23:52:51,702] Trial 91 finished with value: 0.19901683464723727 and parameters: {'max_depth': 14, 'subsample': 0.6627579555637664, 'colsample_bytree': 0.8032733452757308, 'min_child_weight': 1, 'gamma': 0.13715756407378835, 'lambda': 0.08735100889548861, 'alpha': 0.0017451729034268907}. Best is trial 72 with value: 0.19287575690634629.
# [I 2023-08-06 23:52:52,717] Trial 92 finished with value: 0.19012901157684942 and parameters: {'max_depth': 14, 'subsample': 0.6590888225044937, 'colsample_bytree': 0.8014593187928386, 'min_child_weight': 1, 'gamma': 0.12878196168982992, 'lambda': 0.08045295972414256, 'alpha': 0.0019603156031469176}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:52:53,635] Trial 93 finished with value: 0.20246480604829187 and parameters: {'max_depth': 13, 'subsample': 0.6458010798060649, 'colsample_bytree': 0.8150029789726211, 'min_child_weight': 3, 'gamma': 0.21120692371428884, 'lambda': 0.24846181373201726, 'alpha': 0.002418446166514581}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:52:54,409] Trial 94 finished with value: 0.22342135589419915 and parameters: {'max_depth': 13, 'subsample': 0.6204185980795078, 'colsample_bytree': 0.786328435240258, 'min_child_weight': 5, 'gamma': 0.1605182845487929, 'lambda': 0.07279732833575296, 'alpha': 0.0012719943114480531}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:52:55,353] Trial 95 finished with value: 0.2033285746449744 and parameters: {'max_depth': 12, 'subsample': 0.7193424658784675, 'colsample_bytree': 0.7970411323995729, 'min_child_weight': 2, 'gamma': 0.11265937601835446, 'lambda': 0.17338778054231582, 'alpha': 0.0071405185147148074}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:52:56,193] Trial 96 finished with value: 0.20851200690761726 and parameters: {'max_depth': 14, 'subsample': 0.6927906893500374, 'colsample_bytree': 0.7676927325571858, 'min_child_weight': 4, 'gamma': 0.07381041427650546, 'lambda': 0.13048174901250678, 'alpha': 0.0032409549705174146}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:52:57,269] Trial 97 finished with value: 0.20851011617782156 and parameters: {'max_depth': 13, 'subsample': 0.6805625832243247, 'colsample_bytree': 0.8246167127176505, 'min_child_weight': 1, 'gamma': 0.1821259039030659, 'lambda': 0.035270424663423894, 'alpha': 0.0018428265862514435}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:52:57,986] Trial 98 finished with value: 0.24229159460641186 and parameters: {'max_depth': 10, 'subsample': 0.6329182261233519, 'colsample_bytree': 0.8445365558397443, 'min_child_weight': 8, 'gamma': 0.12366862232052515, 'lambda': 0.05580695071638748, 'alpha': 0.0010265389625799775}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:52:58,844] Trial 99 finished with value: 0.20927355373761874 and parameters: {'max_depth': 15, 'subsample': 0.6510751379958057, 'colsample_bytree': 0.8652749058870184, 'min_child_weight': 3, 'gamma': 0.14466902689771532, 'lambda': 0.7815039529532941, 'alpha': 0.004856430217800959}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:52:59,616] Trial 100 finished with value: 0.21146911266182059 and parameters: {'max_depth': 11, 'subsample': 0.6692384087370512, 'colsample_bytree': 0.8084880711536708, 'min_child_weight': 5, 'gamma': 0.21140388128465454, 'lambda': 0.2119477325389318, 'alpha': 0.0006690933573769908}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:53:00,666] Trial 101 finished with value: 0.2045225520733945 and parameters: {'max_depth': 14, 'subsample': 0.6633550362789022, 'colsample_bytree': 0.8047393892685614, 'min_child_weight': 1, 'gamma': 0.13560194389547453, 'lambda': 0.08593117146913444, 'alpha': 0.0015454745343908194}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:53:01,645] Trial 102 finished with value: 0.20399818954715113 and parameters: {'max_depth': 14, 'subsample': 0.658275316861822, 'colsample_bytree': 0.7967441815250488, 'min_child_weight': 2, 'gamma': 0.14777404178588885, 'lambda': 0.1211788253246239, 'alpha': 0.0025060226818196126}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:53:02,793] Trial 103 finished with value: 0.21556452819335759 and parameters: {'max_depth': 15, 'subsample': 0.6980421462293488, 'colsample_bytree': 0.778540102791693, 'min_child_weight': 1, 'gamma': 0.24174802467371928, 'lambda': 0.08446416628400816, 'alpha': 0.0015937273385258715}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:53:03,582] Trial 104 finished with value: 0.21439744759178359 and parameters: {'max_depth': 12, 'subsample': 0.6776129510181839, 'colsample_bytree': 0.8203573983471935, 'min_child_weight': 6, 'gamma': 0.1760822778486796, 'lambda': 0.291340955839102, 'alpha': 0.0019422799678148093}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:53:04,574] Trial 105 finished with value: 0.21020526935511064 and parameters: {'max_depth': 13, 'subsample': 0.6281497230995264, 'colsample_bytree': 0.7875827843425981, 'min_child_weight': 3, 'gamma': 0.08830376990670026, 'lambda': 0.15243362499572127, 'alpha': 0.003833850561270839}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:53:05,514] Trial 106 finished with value: 0.20579918327107188 and parameters: {'max_depth': 14, 'subsample': 0.6395683837350299, 'colsample_bytree': 0.8024522120803856, 'min_child_weight': 2, 'gamma': 0.032777331031900184, 'lambda': 0.048884448896433425, 'alpha': 0.0026950568311381934}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:53:06,498] Trial 107 finished with value: 0.20143338765798707 and parameters: {'max_depth': 15, 'subsample': 0.6636212203421492, 'colsample_bytree': 0.8316129258566117, 'min_child_weight': 1, 'gamma': 0.059817210473941465, 'lambda': 0.07105972457647831, 'alpha': 0.0012553580096514839}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:53:07,319] Trial 108 finished with value: 0.21068619520355006 and parameters: {'max_depth': 12, 'subsample': 0.602196925938264, 'colsample_bytree': 0.8102245669305023, 'min_child_weight': 4, 'gamma': 0.10781811419384917, 'lambda': 0.5310565438448308, 'alpha': 0.0009604752485350867}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:53:07,901] Trial 109 finished with value: 0.3267038250184601 and parameters: {'max_depth': 11, 'subsample': 0.6509793433748126, 'colsample_bytree': 0.8786844592830075, 'min_child_weight': 28, 'gamma': 0.27597080992058165, 'lambda': 0.19686443493275238, 'alpha': 0.002022906925285507}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:53:08,630] Trial 110 finished with value: 0.23403777247158666 and parameters: {'max_depth': 12, 'subsample': 0.6723360630275925, 'colsample_bytree': 0.7640986329720231, 'min_child_weight': 7, 'gamma': 0.12380333424514221, 'lambda': 0.10399214723334849, 'alpha': 0.0005589868002298215}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:53:09,528] Trial 111 finished with value: 0.205876318187161 and parameters: {'max_depth': 14, 'subsample': 0.6799804254251512, 'colsample_bytree': 0.8021211843878141, 'min_child_weight': 3, 'gamma': 0.16069029200680268, 'lambda': 0.08422515105436956, 'alpha': 0.0019719833694960575}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:53:10,463] Trial 112 finished with value: 0.20817457654796523 and parameters: {'max_depth': 14, 'subsample': 0.6886645754877208, 'colsample_bytree': 0.7922077510678509, 'min_child_weight': 2, 'gamma': 0.20649639237816989, 'lambda': 0.06009028441203201, 'alpha': 0.0029176909344528243}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:53:11,427] Trial 113 finished with value: 0.19307715356066096 and parameters: {'max_depth': 13, 'subsample': 0.6604302420429706, 'colsample_bytree': 0.8177520728002381, 'min_child_weight': 2, 'gamma': 0.19228629566609096, 'lambda': 0.14633064490931325, 'alpha': 0.0016072503438397314}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:53:12,487] Trial 114 finished with value: 0.19910054124879642 and parameters: {'max_depth': 13, 'subsample': 0.645900071713809, 'colsample_bytree': 0.8397650258408514, 'min_child_weight': 1, 'gamma': 0.19000742584929925, 'lambda': 0.13384062873759278, 'alpha': 0.0013573222625981598}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:53:13,367] Trial 115 finished with value: 0.2090020263324917 and parameters: {'max_depth': 13, 'subsample': 0.6602032992387685, 'colsample_bytree': 0.8188862211085768, 'min_child_weight': 4, 'gamma': 0.22331967892845703, 'lambda': 0.2528286279865518, 'alpha': 0.0008135879632729832}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:53:14,134] Trial 116 finished with value: 0.23503143237662796 and parameters: {'max_depth': 13, 'subsample': 0.6365731529473387, 'colsample_bytree': 0.7822394564773788, 'min_child_weight': 6, 'gamma': 0.25369575423517693, 'lambda': 0.41267626814466835, 'alpha': 0.0010513616689143577}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:53:15,149] Trial 117 finished with value: 0.20078741265463176 and parameters: {'max_depth': 19, 'subsample': 0.6153568442798008, 'colsample_bytree': 0.8552616362332304, 'min_child_weight': 2, 'gamma': 0.3183214442144631, 'lambda': 0.17611935805344744, 'alpha': 0.004101013060097133}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:53:16,002] Trial 118 finished with value: 0.2192685237028095 and parameters: {'max_depth': 12, 'subsample': 0.66925805936727, 'colsample_bytree': 0.8288207884602424, 'min_child_weight': 5, 'gamma': 0.17656275329387172, 'lambda': 0.3167155806166645, 'alpha': 0.005808974425606572}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:53:16,846] Trial 119 finished with value: 0.2135704329741531 and parameters: {'max_depth': 11, 'subsample': 0.7022447307541613, 'colsample_bytree': 0.8105411721834789, 'min_child_weight': 3, 'gamma': 0.09173186325978265, 'lambda': 0.11065554030745799, 'alpha': 0.0016499593390563135}. Best is trial 92 with value: 0.19012901157684942.
# [I 2023-08-06 23:53:17,892] Trial 120 finished with value: 0.19001186986140045 and parameters: {'max_depth': 10, 'subsample': 0.624903173894448, 'colsample_bytree': 0.7718856635327066, 'min_child_weight': 1, 'gamma': 0.1350231968591301, 'lambda': 0.027953013650844842, 'alpha': 0.0025141840706175023}. Best is trial 120 with value: 0.19001186986140045.
# [I 2023-08-06 23:53:18,448] Trial 121 finished with value: 0.4200663241606242 and parameters: {'max_depth': 10, 'subsample': 0.6221161940370289, 'colsample_bytree': 0.7925024483642062, 'min_child_weight': 50, 'gamma': 0.1533157985861975, 'lambda': 0.0336363661279692, 'alpha': 0.0026143575053906506}. Best is trial 120 with value: 0.19001186986140045.
# [I 2023-08-06 23:53:19,473] Trial 122 finished with value: 0.19771215989768012 and parameters: {'max_depth': 10, 'subsample': 0.6519093080068734, 'colsample_bytree': 0.7716658389804486, 'min_child_weight': 1, 'gamma': 0.1344150020375532, 'lambda': 0.09818155302941647, 'alpha': 0.0035121405842992223}. Best is trial 120 with value: 0.19001186986140045.
# [I 2023-08-06 23:53:20,400] Trial 123 finished with value: 0.1994825798127283 and parameters: {'max_depth': 10, 'subsample': 0.6481658169766635, 'colsample_bytree': 0.7742314775749487, 'min_child_weight': 2, 'gamma': 0.20091733628896624, 'lambda': 0.02485212705435468, 'alpha': 0.0031503207800842015}. Best is trial 120 with value: 0.19001186986140045.
# [I 2023-08-06 23:53:21,204] Trial 124 finished with value: 0.2201335942463607 and parameters: {'max_depth': 10, 'subsample': 0.6349324707832062, 'colsample_bytree': 0.7573312557816408, 'min_child_weight': 4, 'gamma': 0.11628502946021418, 'lambda': 0.04409242791906806, 'alpha': 0.002275832601983936}. Best is trial 120 with value: 0.19001186986140045.
# [I 2023-08-06 23:53:22,335] Trial 125 finished with value: 0.19996518614890402 and parameters: {'max_depth': 10, 'subsample': 0.6547303692560423, 'colsample_bytree': 0.7690106201449981, 'min_child_weight': 1, 'gamma': 0.2330435741842951, 'lambda': 0.14467632308838768, 'alpha': 0.003638156953543194}. Best is trial 120 with value: 0.19001186986140045.
# [I 2023-08-06 23:53:23,176] Trial 126 finished with value: 0.204466436157338 and parameters: {'max_depth': 10, 'subsample': 0.6264735509086481, 'colsample_bytree': 0.7426881964890262, 'min_child_weight': 3, 'gamma': 0.055282009088705245, 'lambda': 0.19653623405907894, 'alpha': 0.00496225386742641}. Best is trial 120 with value: 0.19001186986140045.
# [I 2023-08-06 23:53:24,008] Trial 127 finished with value: 0.20632465158069646 and parameters: {'max_depth': 11, 'subsample': 0.604117307527959, 'colsample_bytree': 0.784408089594178, 'min_child_weight': 3, 'gamma': 0.16757442815817292, 'lambda': 0.0686538085147984, 'alpha': 0.001198027461866194}. Best is trial 120 with value: 0.19001186986140045.
# [I 2023-08-06 23:53:25,159] Trial 128 finished with value: 0.19599576520892065 and parameters: {'max_depth': 11, 'subsample': 0.6141257036784382, 'colsample_bytree': 0.7602887425040502, 'min_child_weight': 1, 'gamma': 0.2899865573579888, 'lambda': 0.11300082819089392, 'alpha': 0.0014593574008183023}. Best is trial 120 with value: 0.19001186986140045.
# [I 2023-08-06 23:53:26,342] Trial 129 finished with value: 0.20233857345600073 and parameters: {'max_depth': 10, 'subsample': 0.5926545292088542, 'colsample_bytree': 0.7588313132805729, 'min_child_weight': 1, 'gamma': 0.33739482095295104, 'lambda': 0.09619174045645548, 'alpha': 0.001475983454894701}. Best is trial 120 with value: 0.19001186986140045.
# [I 2023-08-06 23:53:27,110] Trial 130 finished with value: 0.23125795386838774 and parameters: {'max_depth': 11, 'subsample': 0.585691922753623, 'colsample_bytree': 0.7705189394352028, 'min_child_weight': 5, 'gamma': 0.2903639425440907, 'lambda': 0.12779170162131034, 'alpha': 0.0021104241750041926}. Best is trial 120 with value: 0.19001186986140045.
# [I 2023-08-06 23:53:28,049] Trial 131 finished with value: 0.20598509523492353 and parameters: {'max_depth': 11, 'subsample': 0.6116031181795111, 'colsample_bytree': 0.7782461193198775, 'min_child_weight': 2, 'gamma': 0.2643441878647067, 'lambda': 0.05498297611259353, 'alpha': 0.0008920961455020409}. Best is trial 120 with value: 0.19001186986140045.
# [I 2023-08-06 23:53:29,178] Trial 132 finished with value: 0.21528209546468932 and parameters: {'max_depth': 11, 'subsample': 0.6435458471393539, 'colsample_bytree': 0.7487914708533009, 'min_child_weight': 1, 'gamma': 0.353802127926809, 'lambda': 0.2593975792325918, 'alpha': 0.0033484184474242866}. Best is trial 120 with value: 0.19001186986140045.
# [I 2023-08-06 23:53:29,742] Trial 133 finished with value: 0.30174738616138275 and parameters: {'max_depth': 20, 'subsample': 0.6310692688369005, 'colsample_bytree': 0.7665994943504205, 'min_child_weight': 22, 'gamma': 0.3053569903239547, 'lambda': 0.16194722229815559, 'alpha': 0.002567943052921526}. Best is trial 120 with value: 0.19001186986140045.
# [I 2023-08-06 23:53:30,601] Trial 134 finished with value: 0.21106868989663932 and parameters: {'max_depth': 12, 'subsample': 0.6515620682316063, 'colsample_bytree': 0.7913405538436377, 'min_child_weight': 4, 'gamma': 0.19207956883360447, 'lambda': 0.10608715096774432, 'alpha': 0.0017507944503953761}. Best is trial 120 with value: 0.19001186986140045.
# [I 2023-08-06 23:53:31,506] Trial 135 finished with value: 0.20855511172970292 and parameters: {'max_depth': 11, 'subsample': 0.6674630212174015, 'colsample_bytree': 0.7623512754895649, 'min_child_weight': 2, 'gamma': 0.14358806469014365, 'lambda': 0.22255648279876908, 'alpha': 0.0011377713879250028}. Best is trial 120 with value: 0.19001186986140045.
# ...
# [I 2023-08-07 00:07:23,385] Trial 956 finished with value: 0.19299501085585502 and parameters: {'max_depth': 15, 'subsample': 0.5237671256550345, 'colsample_bytree': 0.9505930656009388, 'min_child_weight': 2, 'gamma': 0.2048363112987663, 'lambda': 6.541221901686102e-05, 'alpha': 0.004363303207153777}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:24,387] Trial 957 finished with value: 0.22342827153296554 and parameters: {'max_depth': 17, 'subsample': 0.500068436113717, 'colsample_bytree': 0.9387431632534704, 'min_child_weight': 3, 'gamma': 0.6393230216868513, 'lambda': 1.9254380174098283e-05, 'alpha': 0.011021880922785927}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:25,862] Trial 958 finished with value: 0.22275534451409257 and parameters: {'max_depth': 20, 'subsample': 0.7442929391334046, 'colsample_bytree': 0.8413588453507242, 'min_child_weight': 1, 'gamma': 0.016326150508580647, 'lambda': 0.00010639519563978829, 'alpha': 2.1498423311376454e-05}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:27,434] Trial 959 finished with value: 0.19069994034900112 and parameters: {'max_depth': 19, 'subsample': 0.5270565042097768, 'colsample_bytree': 0.9280212905354716, 'min_child_weight': 1, 'gamma': 0.5574059264402342, 'lambda': 2.533538387379967e-05, 'alpha': 8.414052917818556e-05}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:28,420] Trial 960 finished with value: 0.20063649334281952 and parameters: {'max_depth': 18, 'subsample': 0.5160763119250765, 'colsample_bytree': 0.8720835632821742, 'min_child_weight': 2, 'gamma': 0.5010541647262716, 'lambda': 3.05210560496468e-05, 'alpha': 0.021127148423623857}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:29,497] Trial 961 finished with value: 0.20425379248432018 and parameters: {'max_depth': 18, 'subsample': 0.5790861974505179, 'colsample_bytree': 0.9569345183206885, 'min_child_weight': 3, 'gamma': 0.34253359581844645, 'lambda': 3.19285382907486e-05, 'alpha': 0.004405466955186652}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:30,590] Trial 962 finished with value: 0.22055253434358907 and parameters: {'max_depth': 13, 'subsample': 0.9062510543477393, 'colsample_bytree': 0.7466060163607454, 'min_child_weight': 2, 'gamma': 0.11885597719944431, 'lambda': 0.025079467372910058, 'alpha': 0.44836207774325654}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:32,104] Trial 963 finished with value: 0.20359500308296558 and parameters: {'max_depth': 18, 'subsample': 0.5319736621821468, 'colsample_bytree': 0.9217252543535173, 'min_child_weight': 1, 'gamma': 0.6997214173575683, 'lambda': 5.6829094128312554e-05, 'alpha': 0.0029128937131469934}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:33,184] Trial 964 finished with value: 0.20466729478983448 and parameters: {'max_depth': 19, 'subsample': 0.6995723624823897, 'colsample_bytree': 0.708288443685744, 'min_child_weight': 2, 'gamma': 0.001373458647433657, 'lambda': 7.100537591461656e-05, 'alpha': 0.01318992761540703}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:34,314] Trial 965 finished with value: 0.20620846573765475 and parameters: {'max_depth': 18, 'subsample': 0.8818541666878138, 'colsample_bytree': 0.697465889035965, 'min_child_weight': 1, 'gamma': 0.053086271393487525, 'lambda': 5.940854665174425e-05, 'alpha': 0.006917225019573508}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:35,408] Trial 966 finished with value: 0.22609495546270408 and parameters: {'max_depth': 17, 'subsample': 0.5115339057670589, 'colsample_bytree': 0.6278336409137784, 'min_child_weight': 3, 'gamma': 0.832853279223256, 'lambda': 9.219059943635527e-05, 'alpha': 0.005125065192701389}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:36,818] Trial 967 finished with value: 0.19781805445844905 and parameters: {'max_depth': 18, 'subsample': 0.5225594031305335, 'colsample_bytree': 0.9772473909565171, 'min_child_weight': 1, 'gamma': 0.4016786010970804, 'lambda': 1.4482329175104786e-05, 'alpha': 0.005817641675067642}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:37,798] Trial 968 finished with value: 0.2055063086618892 and parameters: {'max_depth': 18, 'subsample': 0.811620344012823, 'colsample_bytree': 0.9394414961533909, 'min_child_weight': 3, 'gamma': 0.08161907240156288, 'lambda': 0.013392606926712758, 'alpha': 0.0010201401567593222}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:38,852] Trial 969 finished with value: 0.20478035987181187 and parameters: {'max_depth': 19, 'subsample': 0.6832142631156776, 'colsample_bytree': 0.9506752186097972, 'min_child_weight': 2, 'gamma': 0.03774032597705258, 'lambda': 0.00506470276270168, 'alpha': 0.01815088497587412}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:40,105] Trial 970 finished with value: 0.20897741087849217 and parameters: {'max_depth': 18, 'subsample': 0.8778512093284097, 'colsample_bytree': 0.8814017108241363, 'min_child_weight': 1, 'gamma': 0.17798703760422052, 'lambda': 0.0719724070434349, 'alpha': 0.006124726673378628}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:41,145] Trial 971 finished with value: 0.20298517675543093 and parameters: {'max_depth': 17, 'subsample': 0.7336616852033992, 'colsample_bytree': 0.7945582598313808, 'min_child_weight': 2, 'gamma': 0.01690746195102017, 'lambda': 1.7418136393560297e-05, 'alpha': 0.0039126196929104105}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:42,055] Trial 972 finished with value: 0.21531012458586632 and parameters: {'max_depth': 16, 'subsample': 0.7178268977654648, 'colsample_bytree': 0.9329819438994403, 'min_child_weight': 5, 'gamma': 0.00010414176545392841, 'lambda': 2.1244081629694552e-05, 'alpha': 0.65679001186242}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:43,152] Trial 973 finished with value: 0.22313293943234286 and parameters: {'max_depth': 20, 'subsample': 0.8055751191723252, 'colsample_bytree': 0.7659492055845191, 'min_child_weight': 4, 'gamma': 0.9215877584322818, 'lambda': 0.004127861743804394, 'alpha': 0.025788333325066595}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:44,495] Trial 974 finished with value: 0.24220055252707673 and parameters: {'max_depth': 18, 'subsample': 0.6090765426966058, 'colsample_bytree': 0.7341270437403226, 'min_child_weight': 1, 'gamma': 0.9876822428959188, 'lambda': 0.03615945208293405, 'alpha': 0.26487597307925986}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:45,579] Trial 975 finished with value: 0.20746543211368293 and parameters: {'max_depth': 18, 'subsample': 0.5368115372564533, 'colsample_bytree': 0.9461092512655409, 'min_child_weight': 3, 'gamma': 0.6547585954207895, 'lambda': 0.00014878848472982647, 'alpha': 0.010274347666394288}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:46,196] Trial 976 finished with value: 0.3012517170059641 and parameters: {'max_depth': 19, 'subsample': 0.5879221465122876, 'colsample_bytree': 0.7329627439399571, 'min_child_weight': 21, 'gamma': 0.1585808436636275, 'lambda': 1.48755324093448e-05, 'alpha': 0.04900172273141297}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:47,229] Trial 977 finished with value: 0.19656396760158218 and parameters: {'max_depth': 13, 'subsample': 0.6494066396624207, 'colsample_bytree': 0.923482294293422, 'min_child_weight': 2, 'gamma': 0.1066918395200671, 'lambda': 0.00021420033865639977, 'alpha': 0.35707888014790795}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:48,379] Trial 978 finished with value: 0.21060144000704054 and parameters: {'max_depth': 14, 'subsample': 0.5470928878208743, 'colsample_bytree': 0.7725406915674266, 'min_child_weight': 1, 'gamma': 0.2811835978587002, 'lambda': 1.054758176602806e-05, 'alpha': 0.0658948166669938}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:49,465] Trial 979 finished with value: 0.21145330994030145 and parameters: {'max_depth': 18, 'subsample': 0.8870134384206765, 'colsample_bytree': 0.9050797766469975, 'min_child_weight': 2, 'gamma': 0.06004785982019893, 'lambda': 3.674389882721676e-05, 'alpha': 0.19260698246405744}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:50,619] Trial 980 finished with value: 0.21578193261189868 and parameters: {'max_depth': 18, 'subsample': 0.7711101688274792, 'colsample_bytree': 0.9357617891721569, 'min_child_weight': 3, 'gamma': 0.6097154327636816, 'lambda': 0.006112122769215498, 'alpha': 0.1002776345817465}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:51,643] Trial 981 finished with value: 0.20109232373681946 and parameters: {'max_depth': 18, 'subsample': 0.5283874595747967, 'colsample_bytree': 0.7259298508415111, 'min_child_weight': 1, 'gamma': 0.028087385041761136, 'lambda': 4.086189883706114e-05, 'alpha': 0.13002895407417323}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:52,693] Trial 982 finished with value: 0.20173246274708947 and parameters: {'max_depth': 17, 'subsample': 0.5575580684527791, 'colsample_bytree': 0.7801908331310095, 'min_child_weight': 2, 'gamma': 0.3685054429503038, 'lambda': 0.00015826010550385142, 'alpha': 0.00870726569715222}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:53,535] Trial 983 finished with value: 0.21710271124600192 and parameters: {'max_depth': 18, 'subsample': 0.519562965815256, 'colsample_bytree': 0.6926078126892923, 'min_child_weight': 4, 'gamma': 0.12867541785143333, 'lambda': 3.329585452397427e-05, 'alpha': 0.17086397834756994}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:54,686] Trial 984 finished with value: 0.21780105615157272 and parameters: {'max_depth': 15, 'subsample': 0.9737599840043998, 'colsample_bytree': 0.830704213427287, 'min_child_weight': 1, 'gamma': 0.042267841168346865, 'lambda': 2.3094737993822116e-05, 'alpha': 0.042581117404491435}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:55,684] Trial 985 finished with value: 0.20847789760782648 and parameters: {'max_depth': 16, 'subsample': 0.5393435518200632, 'colsample_bytree': 0.8167823297053447, 'min_child_weight': 3, 'gamma': 0.07555578145478001, 'lambda': 0.016101270058444347, 'alpha': 0.013147387440320388}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:57,005] Trial 986 finished with value: 0.1981145678061628 and parameters: {'max_depth': 19, 'subsample': 0.5092032019836291, 'colsample_bytree': 0.9646266802393207, 'min_child_weight': 1, 'gamma': 0.2804054455905659, 'lambda': 1.351913857760474e-05, 'alpha': 0.22494002390664608}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:58,067] Trial 987 finished with value: 0.2074495116771596 and parameters: {'max_depth': 18, 'subsample': 0.5676947524540171, 'colsample_bytree': 0.9166443326700945, 'min_child_weight': 2, 'gamma': 0.41928700771730015, 'lambda': 3.0730409198602044e-05, 'alpha': 0.11811448321018318}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:07:59,327] Trial 988 finished with value: 0.19962917555175183 and parameters: {'max_depth': 17, 'subsample': 0.5303133018587155, 'colsample_bytree': 0.9437132733021766, 'min_child_weight': 1, 'gamma': 0.01747604833295075, 'lambda': 0.00032565629575214295, 'alpha': 0.000513835987572919}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:08:00,240] Trial 989 finished with value: 0.21111232359873192 and parameters: {'max_depth': 18, 'subsample': 0.5004744764037418, 'colsample_bytree': 0.8467777374509958, 'min_child_weight': 3, 'gamma': 0.09124513876874892, 'lambda': 0.0001057653263198654, 'alpha': 0.0036324862777731264}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:08:01,391] Trial 990 finished with value: 0.21344263275838588 and parameters: {'max_depth': 18, 'subsample': 0.8991649878964534, 'colsample_bytree': 0.8983237142370378, 'min_child_weight': 2, 'gamma': 0.2470525198207368, 'lambda': 0.004273329037715155, 'alpha': 0.03745234570602467}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:08:01,929] Trial 991 finished with value: 0.43703723745514783 and parameters: {'max_depth': 19, 'subsample': 0.551898093397714, 'colsample_bytree': 0.8608662674737152, 'min_child_weight': 47, 'gamma': 0.0010994080685146554, 'lambda': 0.00023900487829646634, 'alpha': 0.5517818773962382}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:08:02,981] Trial 992 finished with value: 0.2036642881352817 and parameters: {'max_depth': 20, 'subsample': 0.9231329294121414, 'colsample_bytree': 0.9288338625245125, 'min_child_weight': 4, 'gamma': 0.05380208945228433, 'lambda': 0.008589995825746141, 'alpha': 0.0002021130081641381}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:08:04,580] Trial 993 finished with value: 0.21522207245121044 and parameters: {'max_depth': 18, 'subsample': 0.5189532339980878, 'colsample_bytree': 0.9570474897035, 'min_child_weight': 1, 'gamma': 0.9447402523198594, 'lambda': 0.0002861786858455544, 'alpha': 0.005438447899009879}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:08:05,832] Trial 994 finished with value: 0.2268204794877593 and parameters: {'max_depth': 18, 'subsample': 0.9928715539507202, 'colsample_bytree': 0.9081446768664334, 'min_child_weight': 1, 'gamma': 0.029821675632852384, 'lambda': 0.00017623615500993503, 'alpha': 0.00017811181509580425}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:08:06,972] Trial 995 finished with value: 0.20116888090131488 and parameters: {'max_depth': 13, 'subsample': 0.8263513356143073, 'colsample_bytree': 0.9228887192043634, 'min_child_weight': 3, 'gamma': 0.0631845321705258, 'lambda': 0.00037858352449472455, 'alpha': 1.5054072943629346e-05}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:08:07,880] Trial 996 finished with value: 0.19333609915761668 and parameters: {'max_depth': 18, 'subsample': 0.5404540405830129, 'colsample_bytree': 0.8865054832887785, 'min_child_weight': 2, 'gamma': 0.14414516825466994, 'lambda': 4.231231985575867e-05, 'alpha': 0.0754259855785313}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:08:09,041] Trial 997 finished with value: 0.19547141297029633 and parameters: {'max_depth': 19, 'subsample': 0.5290877132167943, 'colsample_bytree': 0.9358984696483358, 'min_child_weight': 1, 'gamma': 0.2102723247685296, 'lambda': 0.04890375103316637, 'alpha': 0.3108127824744309}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:08:10,309] Trial 998 finished with value: 0.23043679590015181 and parameters: {'max_depth': 18, 'subsample': 0.6714020795064061, 'colsample_bytree': 0.9162437620042282, 'min_child_weight': 2, 'gamma': 0.7890044010172889, 'lambda': 8.078710839830052e-05, 'alpha': 0.15419914667794482}. Best is trial 514 with value: 0.1760380944057804.
# [I 2023-08-07 00:08:11,377] Trial 999 finished with value: 0.21677344511901028 and parameters: {'max_depth': 17, 'subsample': 0.8578605215016506, 'colsample_bytree': 0.7559773097166723, 'min_child_weight': 3, 'gamma': 0.03429307931950562, 'lambda': 2.0905101463431855e-05, 'alpha': 0.00014860328523189605}. Best is trial 514 with value: 0.1760380944057804.
# Best parameters: {'max_depth': 18, 'subsample': 0.5236088397410353, 'colsample_bytree': 0.9081020201822949, 'min_child_weight': 1, 'gamma': 0.018902786999403336, 'lambda': 0.002946024021403057, 'alpha': 0.21131772406300453}

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import log_loss
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold
import optuna
import warnings
from tqdm import tqdm
warnings.simplefilter('ignore')

# %%
# 設定値
class CFG:
    # 変更するパラメータ
    n_folds = 5 # 公差検証の分割数(多くて20)
    n_trials = 100 # ハイパーパラメータチューニングの試行回数(100)
    device_type = "cpu"
    # device_type = "gpu"
    boosting_type = "gbdt"
    # boosting_type = "dart"
    
    
    # その他設定値
    learning_rate = 0.01
    seed = 3407 
    target_col = 'Class'
    num_boost_round = 50500
    early_stopping_round = 300
    verbose_eval = 0  # この数字を1にすると学習時のスコア推移がコマンドライン表示される

# %%
# BASE_DIR = '/kaggle/input/icr-identify-age-related-conditions/'
BASE_DIR = '../data'
train_df = pd.read_csv(f'{BASE_DIR}/train.csv')
greeks_df = pd.read_csv(f'{BASE_DIR}/greeks.csv')
test_df = pd.read_csv(f'{BASE_DIR}/test.csv')
submission_df = pd.read_csv(f'{BASE_DIR}/sample_submission.csv')

test_df[CFG.target_col] = -1
all_df = pd.concat([train_df, test_df])

# %% [markdown]
# BC, CLはいらんかも

# %%
numerical_features = ['AB', 'AF', 'AH', 'AM', 'AR', 'AX', 'AY', 'AZ', 'BC', 'BD ', 'BN',
       'BP', 'BQ', 'BR', 'BZ', 'CB', 'CC', 'CD ', 'CF', 'CH', 'CL', 'CR', 'CS',
       'CU', 'CW ', 'DA', 'DE', 'DF', 'DH', 'DI', 'DL', 'DN', 'DU', 'DV', 'DY',
       'EB', 'EE', 'EG', 'EH', 'EL', 'EP', 'EU', 'FC', 'FD ', 'FE', 'FI',
       'FL', 'FR', 'FS', 'GB', 'GE', 'GF', 'GH', 'GI', 'GL']
categorical_features = ['EJ']
features = numerical_features + categorical_features

# %% [markdown]
# ### balanced loglossの計算（学習で使う？）

# %%
# 前処理
def Preprocessing(input_df: pd.DataFrame)->pd.DataFrame:
    output_df = input_df.copy()
    output_df['EJ'] = input_df['EJ'].replace({'A': 0, 'B': 1})
    return output_df

all_df = Preprocessing(all_df)

train_df = all_df[all_df[CFG.target_col] != -1].copy()
test_df = all_df[all_df[CFG.target_col] == -1].copy()

# %%
# 評価基準
def balanced_log_loss(y_true, y_pred):
    N = len(y_true)

    # Nc is the number of observations
    N_1 = np.sum(y_true == 1, axis=0)
    N_0 = np.sum(y_true == 0, axis=0)

    # In order to avoid the extremes of the log function, each predicted probability 𝑝 is replaced with max(min(𝑝,1−10−15),10−15)
    y_pred = np.maximum(np.minimum(y_pred, 1 - 1e-15), 1e-15)

    # balanced logarithmic loss
    loss_numerator = - (1/N_0) * np.sum((1 - y_true) * np.log(1-y_pred)) - (1/N_1) * np.sum(y_true * np.log(y_pred))

    return loss_numerator / 2

# Classの０，１の割合をそれぞれ計算
def calc_log_loss_weight(y_true):
    nc = np.bincount(y_true)
    w0, w1 = 1/(nc[0]/y_true.shape[0]), 1/(nc[1]/y_true.shape[0])
    return w0, w1

# %%
def objective(trial):
    # light-gbm設定値
    lgb_params = {
        # 探索するパラメータ
        'verbosity': -1, # 学習途中の情報を表示するかどうか
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.2, 1.0),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.2, 1.0),
        # "bagging_freq": trial.suggest_int("bagging_freq", 1, 7),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
        
        # 固定値
        "boosting_type": CFG.boosting_type,
        "device_type": CFG.device_type,
        "objective": "binary",
        "learning_rate": CFG.learning_rate,
        "metric": "binary_logloss",
        'seed': CFG.seed,
        'n_jobs': -1, # -1でコア数をマックスで使う
        'is_unbalance':True, # 不均衡データの場合にTrueにする
    }
    
    scores = []
    # K-分割交差検証(層化抽出法)
    kfold = StratifiedKFold(n_splits = CFG.n_folds, shuffle = True, random_state = CFG.seed)
    pbar = tqdm(enumerate(kfold.split(train_df, train_df[CFG.target_col])))
    for fold, (train_index, valid_index) in pbar:
    # for fold, (train_index, valid_index) in enumerate(kfold.split(train_df, train_df[CFG.target_col])):
        # 現在の試行回数を出力
        pbar.set_description("[train] trials {}".format(trial.number+1))
        
        x_train = train_df[features].iloc[train_index]
        y_train = train_df[CFG.target_col].iloc[train_index]
        x_valid = train_df[features].iloc[valid_index]
        y_valid = train_df[CFG.target_col].iloc[valid_index]
        
        # 訓練データの重みを計算
        train_w0, train_w1 = calc_log_loss_weight(y_train)
        # 検証データの重みを計算
        valid_w0, valid_w1 = calc_log_loss_weight(y_valid)
        # 訓練データをlgb用に変換
        lgb_train = lgb.Dataset(x_train, y_train, weight=y_train.map({0: train_w0, 1: train_w1}), categorical_feature=categorical_features)
        # lgb_train = lgb.Dataset(x_train, y_train, categorical_feature=categorical_features)
        # 検証データをlgb用に変換
        lgb_valid = lgb.Dataset(x_valid, y_valid, weight=y_valid.map({0: valid_w0, 1: valid_w1}), categorical_feature=categorical_features)
        # lgb_valid = lgb.Dataset(x_valid, y_valid, categorical_feature=categorical_features)
        
        model = lgb.train(
                    params = lgb_params,
                    train_set = lgb_train,
                    num_boost_round = CFG.num_boost_round,
                    valid_sets = [lgb_train, lgb_valid],
                    early_stopping_rounds = CFG.early_stopping_round,
                    verbose_eval = CFG.verbose_eval,
                    # 学習段階でbalanced_log_lossを使う場合はコメントアウト外す
                    # feval = lgb_metric,
                )
        # 予測
        preds = model.predict(x_valid)
        # 予測値をラベルに変換
        # pred_labels = np.rint(preds)
        # 評価
        # val_score = balanced_log_loss(y_valid, pred_labels)
        val_score = balanced_log_loss(y_valid, preds)
        
        scores.append(val_score)
    # クロスバリデーションの平均値を計算
    mean_score = np.mean(scores)
    
    return mean_score

# %%
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=CFG.n_trials)
# Out:
# [I 2023-06-03 16:37:00,260] A new study created in memory with name: no-name-ad4d7ee9-b9dc-47e5-9854-1becff7422ed
# [train] trials 1: : 5it [00:07,  1.43s/it]
# [I 2023-06-03 16:37:07,403] Trial 0 finished with value: 0.32094636606285587 and parameters: {'lambda_l1': 0.00015551180232562748, 'lambda_l2': 0.00018159023485480913, 'num_leaves': 136, 'feature_fraction': 0.8573122025422735, 'bagging_fraction': 0.34142413338657995, 'min_child_samples': 9}. Best is trial 0 with value: 0.32094636606285587.
# [train] trials 2: : 5it [00:07,  1.53s/it]
# [I 2023-06-03 16:37:15,040] Trial 1 finished with value: 0.30759567415171085 and parameters: {'lambda_l1': 4.7676669032534814e-08, 'lambda_l2': 1.4014796780414881e-08, 'num_leaves': 177, 'feature_fraction': 0.9978515353572892, 'bagging_fraction': 0.5046112909546834, 'min_child_samples': 17}. Best is trial 1 with value: 0.30759567415171085.
# [train] trials 3: : 5it [00:03,  1.28it/s]
# [I 2023-06-03 16:37:18,950] Trial 2 finished with value: 0.25394575364690397 and parameters: {'lambda_l1': 2.665064201430904, 'lambda_l2': 0.00014946895064834668, 'num_leaves': 134, 'feature_fraction': 0.8265739892082797, 'bagging_fraction': 0.5158511742554701, 'min_child_samples': 19}. Best is trial 2 with value: 0.25394575364690397.
# [train] trials 4: : 5it [00:02,  1.81it/s]
# [I 2023-06-03 16:37:21,725] Trial 3 finished with value: 0.23149601465879138 and parameters: {'lambda_l1': 3.5264777720821005e-05, 'lambda_l2': 0.011710896363216318, 'num_leaves': 46, 'feature_fraction': 0.21482993664719263, 'bagging_fraction': 0.20709275302327443, 'min_child_samples': 45}. Best is trial 3 with value: 0.23149601465879138.
# [train] trials 5: : 5it [00:02,  1.79it/s]
# [I 2023-06-03 16:37:24,537] Trial 4 finished with value: 0.23740309632549414 and parameters: {'lambda_l1': 6.0281259174556595e-06, 'lambda_l2': 1.2661032213044106e-08, 'num_leaves': 239, 'feature_fraction': 0.22166371838368742, 'bagging_fraction': 0.5248268250391549, 'min_child_samples': 75}. Best is trial 3 with value: 0.23149601465879138.
# [train] trials 6: : 5it [00:03,  1.44it/s]
# [I 2023-06-03 16:37:28,018] Trial 5 finished with value: 0.26276743638873484 and parameters: {'lambda_l1': 3.0027618724039257e-05, 'lambda_l2': 0.40871161650992505, 'num_leaves': 112, 'feature_fraction': 0.2118778426770126, 'bagging_fraction': 0.37681727929642383, 'min_child_samples': 28}. Best is trial 3 with value: 0.23149601465879138.
# [train] trials 7: : 5it [00:03,  1.59it/s]
# [I 2023-06-03 16:37:31,172] Trial 6 finished with value: 0.22900427153758565 and parameters: {'lambda_l1': 5.912881546918506e-07, 'lambda_l2': 0.0007433379797766481, 'num_leaves': 117, 'feature_fraction': 0.4032490989949805, 'bagging_fraction': 0.8997915793568716, 'min_child_samples': 42}. Best is trial 6 with value: 0.22900427153758565.
# [train] trials 8: : 5it [00:06,  1.28s/it]
# [I 2023-06-03 16:37:37,604] Trial 7 finished with value: 0.279394660525104 and parameters: {'lambda_l1': 7.003974393595765e-05, 'lambda_l2': 0.13764760150116198, 'num_leaves': 116, 'feature_fraction': 0.4437699801895815, 'bagging_fraction': 0.7373780275549142, 'min_child_samples': 10}. Best is trial 6 with value: 0.22900427153758565.
# [train] trials 9: : 5it [00:03,  1.38it/s]
# [I 2023-06-03 16:37:41,248] Trial 8 finished with value: 0.247355746549509 and parameters: {'lambda_l1': 3.285401020563277, 'lambda_l2': 0.1847149675088128, 'num_leaves': 126, 'feature_fraction': 0.8564763830329116, 'bagging_fraction': 0.7550502829235513, 'min_child_samples': 24}. Best is trial 6 with value: 0.22900427153758565.
# [train] trials 10: : 5it [00:03,  1.40it/s]
# [I 2023-06-03 16:37:44,839] Trial 9 finished with value: 0.23511177958812643 and parameters: {'lambda_l1': 3.2836111743264095e-08, 'lambda_l2': 8.140763929864675e-07, 'num_leaves': 187, 'feature_fraction': 0.8544474488125218, 'bagging_fraction': 0.985953246507252, 'min_child_samples': 44}. Best is trial 6 with value: 0.22900427153758565.
# [train] trials 11: : 5it [00:04,  1.05it/s]
# [I 2023-06-03 16:37:49,664] Trial 10 finished with value: 0.2356463991431188 and parameters: {'lambda_l1': 0.01394963406070198, 'lambda_l2': 7.290502927001544, 'num_leaves': 29, 'feature_fraction': 0.508622215006625, 'bagging_fraction': 0.9980419849524695, 'min_child_samples': 85}. Best is trial 6 with value: 0.22900427153758565.
# [train] trials 12: : 5it [00:03,  1.48it/s]
# [I 2023-06-03 16:37:53,105] Trial 11 finished with value: 0.22839957865917845 and parameters: {'lambda_l1': 9.093762986460648e-07, 'lambda_l2': 0.0033549702321122505, 'num_leaves': 32, 'feature_fraction': 0.36477138640566154, 'bagging_fraction': 0.20216513519825968, 'min_child_samples': 56}. Best is trial 11 with value: 0.22839957865917845.
# [train] trials 13: : 5it [00:03,  1.61it/s]
# [I 2023-06-03 16:37:56,268] Trial 12 finished with value: 0.23002897623222504 and parameters: {'lambda_l1': 9.439907543783978e-07, 'lambda_l2': 0.0005485134923518687, 'num_leaves': 68, 'feature_fraction': 0.42047783425977836, 'bagging_fraction': 0.21080249791209665, 'min_child_samples': 64}. Best is trial 11 with value: 0.22839957865917845.
# [train] trials 14: : 5it [00:03,  1.40it/s]
# [I 2023-06-03 16:37:59,887] Trial 13 finished with value: 0.23206516124341822 and parameters: {'lambda_l1': 5.057431863728924e-07, 'lambda_l2': 0.0045261890998930954, 'num_leaves': 14, 'feature_fraction': 0.37481010098857764, 'bagging_fraction': 0.6956494891285819, 'min_child_samples': 58}. Best is trial 11 with value: 0.22839957865917845.
# [train] trials 15: : 5it [00:03,  1.46it/s]
# [I 2023-06-03 16:38:03,339] Trial 14 finished with value: 0.22722703503640612 and parameters: {'lambda_l1': 2.0655534977842916e-08, 'lambda_l2': 1.6031354413623147e-05, 'num_leaves': 80, 'feature_fraction': 0.5685148988908066, 'bagging_fraction': 0.8739623144592544, 'min_child_samples': 43}. Best is trial 14 with value: 0.22722703503640612.
# [train] trials 16: : 5it [00:03,  1.54it/s]
# [I 2023-06-03 16:38:06,625] Trial 15 finished with value: 0.23759810932788303 and parameters: {'lambda_l1': 1.8159529155291332e-08, 'lambda_l2': 1.385222425265972e-05, 'num_leaves': 69, 'feature_fraction': 0.6065948803392329, 'bagging_fraction': 0.8346999847668894, 'min_child_samples': 95}. Best is trial 14 with value: 0.22722703503640612.
# [train] trials 17: : 5it [00:03,  1.59it/s]
# [I 2023-06-03 16:38:09,822] Trial 16 finished with value: 0.23048116045643513 and parameters: {'lambda_l1': 1.0561349549112247e-08, 'lambda_l2': 7.786229169616714e-06, 'num_leaves': 82, 'feature_fraction': 0.6025081629770217, 'bagging_fraction': 0.6458635502727161, 'min_child_samples': 66}. Best is trial 14 with value: 0.22722703503640612.
# [train] trials 18: : 5it [00:03,  1.45it/s]
# [I 2023-06-03 16:38:13,311] Trial 17 finished with value: 0.22780696727338504 and parameters: {'lambda_l1': 1.967790964126402e-07, 'lambda_l2': 0.008031015404052249, 'num_leaves': 45, 'feature_fraction': 0.670126811700412, 'bagging_fraction': 0.6209219353627237, 'min_child_samples': 35}. Best is trial 14 with value: 0.22722703503640612.
# [train] trials 19: : 5it [00:03,  1.37it/s]
# [I 2023-06-03 16:38:17,005] Trial 18 finished with value: 0.21299345281896337 and parameters: {'lambda_l1': 1.198794051669309e-07, 'lambda_l2': 1.4648576249159273e-05, 'num_leaves': 7, 'feature_fraction': 0.6674267408686387, 'bagging_fraction': 0.8235086108719233, 'min_child_samples': 35}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 20: : 5it [00:03,  1.50it/s]
# [I 2023-06-03 16:38:20,377] Trial 19 finished with value: 0.2196677427765453 and parameters: {'lambda_l1': 3.635640339207396e-06, 'lambda_l2': 1.069446793952108e-06, 'num_leaves': 4, 'feature_fraction': 0.6959199198344643, 'bagging_fraction': 0.8392107521254385, 'min_child_samples': 31}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 21: : 5it [00:05,  1.10s/it]
# [I 2023-06-03 16:38:25,918] Trial 20 finished with value: 0.23261878486235466 and parameters: {'lambda_l1': 0.0011218263971091076, 'lambda_l2': 2.9701199061497875e-07, 'num_leaves': 3, 'feature_fraction': 0.7185882277981175, 'bagging_fraction': 0.8057254254939001, 'min_child_samples': 33}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 22: : 5it [00:03,  1.49it/s]
# [I 2023-06-03 16:38:29,315] Trial 21 finished with value: 0.221100801639826 and parameters: {'lambda_l1': 1.0909760494516755e-07, 'lambda_l2': 1.207595106750081e-05, 'num_leaves': 4, 'feature_fraction': 0.5412563096887866, 'bagging_fraction': 0.8808194546678052, 'min_child_samples': 37}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 23: : 5it [00:03,  1.39it/s]
# [I 2023-06-03 16:38:32,944] Trial 22 finished with value: 0.21640362648886624 and parameters: {'lambda_l1': 6.760294362223933e-06, 'lambda_l2': 1.5931862420141227e-06, 'num_leaves': 4, 'feature_fraction': 0.6971025927657915, 'bagging_fraction': 0.9256316243864229, 'min_child_samples': 35}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 24: : 5it [00:04,  1.04it/s]
# [I 2023-06-03 16:38:37,788] Trial 23 finished with value: 0.24360525495855065 and parameters: {'lambda_l1': 4.541269273908443e-06, 'lambda_l2': 6.831455012244282e-07, 'num_leaves': 32, 'feature_fraction': 0.7157789774129474, 'bagging_fraction': 0.9267678341291508, 'min_child_samples': 24}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 25: : 5it [00:02,  1.78it/s]
# [I 2023-06-03 16:38:40,643] Trial 24 finished with value: 0.23295072364907435 and parameters: {'lambda_l1': 4.646442329326293e-06, 'lambda_l2': 2.967250125490122e-06, 'num_leaves': 58, 'feature_fraction': 0.6801294961808493, 'bagging_fraction': 0.8143089383405832, 'min_child_samples': 51}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 26: : 5it [00:04,  1.24it/s]
# [I 2023-06-03 16:38:44,733] Trial 25 finished with value: 0.23342864074787478 and parameters: {'lambda_l1': 1.4034116138250062e-07, 'lambda_l2': 1.3238883214749028e-07, 'num_leaves': 21, 'feature_fraction': 0.7680747993990757, 'bagging_fraction': 0.9472970262221304, 'min_child_samples': 31}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 27: : 5it [00:08,  1.72s/it]
# [I 2023-06-03 16:38:53,373] Trial 26 finished with value: 0.2675308446057703 and parameters: {'lambda_l1': 3.2512567616075796e-06, 'lambda_l2': 3.999267600020373e-05, 'num_leaves': 92, 'feature_fraction': 0.6507638676778618, 'bagging_fraction': 0.7822184371139839, 'min_child_samples': 16}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 28: : 5it [00:05,  1.15s/it]
# [I 2023-06-03 16:38:59,186] Trial 27 finished with value: 0.23223775766168195 and parameters: {'lambda_l1': 1.5226183318502979e-05, 'lambda_l2': 1.846661038012712e-06, 'num_leaves': 49, 'feature_fraction': 0.7723521692684916, 'bagging_fraction': 0.8542872149322196, 'min_child_samples': 53}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 29: : 5it [00:12,  2.41s/it]
# [I 2023-06-03 16:39:11,301] Trial 28 finished with value: 0.36321909359148363 and parameters: {'lambda_l1': 1.4834858449380136e-06, 'lambda_l2': 5.3019535161244795e-05, 'num_leaves': 162, 'feature_fraction': 0.6467939119324669, 'bagging_fraction': 0.9292782804020121, 'min_child_samples': 5}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 30: : 5it [00:03,  1.48it/s]
# [I 2023-06-03 16:39:14,721] Trial 29 finished with value: 0.23006679641462752 and parameters: {'lambda_l1': 0.00023586982023845592, 'lambda_l2': 1.210401578714439e-07, 'num_leaves': 223, 'feature_fraction': 0.7588409931904073, 'bagging_fraction': 0.7088527552898499, 'min_child_samples': 39}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 31: : 5it [00:05,  1.09s/it]
# [I 2023-06-03 16:39:20,228] Trial 30 finished with value: 0.23598300591820723 and parameters: {'lambda_l1': 2.3173173846407064e-07, 'lambda_l2': 3.876448968879592e-06, 'num_leaves': 15, 'feature_fraction': 0.6162291451671315, 'bagging_fraction': 0.8305005769302127, 'min_child_samples': 26}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 32: : 5it [00:04,  1.07it/s]
# [I 2023-06-03 16:39:24,941] Trial 31 finished with value: 0.22498127009508134 and parameters: {'lambda_l1': 9.643783878725426e-08, 'lambda_l2': 8.001857857618851e-06, 'num_leaves': 3, 'feature_fraction': 0.5499625702543365, 'bagging_fraction': 0.8798578970661259, 'min_child_samples': 36}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 33: : 5it [00:05,  1.10s/it]
# [I 2023-06-03 16:39:30,479] Trial 32 finished with value: 0.22376340924522595 and parameters: {'lambda_l1': 6.853659969674168e-08, 'lambda_l2': 5.673929771820749e-05, 'num_leaves': 6, 'feature_fraction': 0.6980340898868416, 'bagging_fraction': 0.8967546735601326, 'min_child_samples': 50}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 34: : 5it [00:06,  1.30s/it]
# [I 2023-06-03 16:39:37,051] Trial 33 finished with value: 0.2496944948295455 and parameters: {'lambda_l1': 8.558564008206614e-08, 'lambda_l2': 1.4761575489488778e-06, 'num_leaves': 32, 'feature_fraction': 0.5590588686234901, 'bagging_fraction': 0.7639037272168894, 'min_child_samples': 21}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 35: : 5it [00:08,  1.63s/it]
# [I 2023-06-03 16:39:45,226] Trial 34 finished with value: 0.27622163813925227 and parameters: {'lambda_l1': 4.959641811318255e-07, 'lambda_l2': 8.767359989119662e-08, 'num_leaves': 21, 'feature_fraction': 0.6445465704369323, 'bagging_fraction': 0.9606406125234783, 'min_child_samples': 14}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 36: : 5it [00:06,  1.36s/it]
# [I 2023-06-03 16:39:52,046] Trial 35 finished with value: 0.22609333088906353 and parameters: {'lambda_l1': 2.1279255474762375e-06, 'lambda_l2': 0.00022065765454905463, 'num_leaves': 45, 'feature_fraction': 0.9433885602539817, 'bagging_fraction': 0.8767582755850011, 'min_child_samples': 38}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 37: : 5it [00:05,  1.18s/it]
# [I 2023-06-03 16:39:57,970] Trial 36 finished with value: 0.22803662260158966 and parameters: {'lambda_l1': 1.4461058192118763e-05, 'lambda_l2': 4.034108193555557e-06, 'num_leaves': 154, 'feature_fraction': 0.7967909591404774, 'bagging_fraction': 0.8170917729998644, 'min_child_samples': 33}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 38: : 5it [00:05,  1.09s/it]
# [I 2023-06-03 16:40:03,489] Trial 37 finished with value: 0.24448782062304825 and parameters: {'lambda_l1': 3.8437554682585914e-08, 'lambda_l2': 3.988309874891997e-08, 'num_leaves': 19, 'feature_fraction': 0.719001903352487, 'bagging_fraction': 0.9129735236975023, 'min_child_samples': 29}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 39: : 5it [00:06,  1.32s/it]
# [I 2023-06-03 16:40:10,141] Trial 38 finished with value: 0.2727713853745037 and parameters: {'lambda_l1': 3.1765811271799683e-07, 'lambda_l2': 4.219214694536216e-07, 'num_leaves': 2, 'feature_fraction': 0.8132702360666562, 'bagging_fraction': 0.9651979314785897, 'min_child_samples': 20}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 40: : 5it [00:03,  1.51it/s]
# [I 2023-06-03 16:40:13,505] Trial 39 finished with value: 0.22964287440993553 and parameters: {'lambda_l1': 8.789072884972209e-06, 'lambda_l2': 1.059120707910107e-06, 'num_leaves': 96, 'feature_fraction': 0.5189366801083991, 'bagging_fraction': 0.7884435408185425, 'min_child_samples': 47}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 41: : 5it [00:04,  1.11it/s]
# [I 2023-06-03 16:40:18,063] Trial 40 finished with value: 0.22725685119228278 and parameters: {'lambda_l1': 5.2058985920811905e-05, 'lambda_l2': 2.3963045767535186e-05, 'num_leaves': 44, 'feature_fraction': 0.729446882251724, 'bagging_fraction': 0.8652554938421217, 'min_child_samples': 38}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 42: : 5it [00:04,  1.01it/s]
# [I 2023-06-03 16:40:23,091] Trial 41 finished with value: 0.2591101762392993 and parameters: {'lambda_l1': 5.8489653067478656e-08, 'lambda_l2': 9.935680350688848e-05, 'num_leaves': 2, 'feature_fraction': 0.6884558848712095, 'bagging_fraction': 0.9134783163488476, 'min_child_samples': 50}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 43: : 5it [00:04,  1.06it/s]
# [I 2023-06-03 16:40:27,848] Trial 42 finished with value: 0.23118792229345378 and parameters: {'lambda_l1': 8.144329237721867e-08, 'lambda_l2': 4.8149943560596954e-05, 'num_leaves': 11, 'feature_fraction': 0.6859097600496264, 'bagging_fraction': 0.9050698591056662, 'min_child_samples': 46}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 44: : 5it [00:04,  1.05it/s]
# [I 2023-06-03 16:40:32,666] Trial 43 finished with value: 0.22737473055589702 and parameters: {'lambda_l1': 1.6366856550494774e-06, 'lambda_l2': 7.719299352560113e-06, 'num_leaves': 30, 'feature_fraction': 0.6331167823135538, 'bagging_fraction': 0.8501456686193537, 'min_child_samples': 61}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 45: : 5it [00:03,  1.40it/s]
# [I 2023-06-03 16:40:36,315] Trial 44 finished with value: 0.2307336237022073 and parameters: {'lambda_l1': 2.6128336729929227e-07, 'lambda_l2': 0.00013387434479298954, 'num_leaves': 23, 'feature_fraction': 0.5880083455544677, 'bagging_fraction': 0.9824951097182762, 'min_child_samples': 73}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 46: : 5it [00:05,  1.13s/it]
# [I 2023-06-03 16:40:41,996] Trial 45 finished with value: 0.23066666907092714 and parameters: {'lambda_l1': 2.728903343139432e-08, 'lambda_l2': 2.1646439786960486e-05, 'num_leaves': 58, 'feature_fraction': 0.7388490758980176, 'bagging_fraction': 0.9475677998889795, 'min_child_samples': 42}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 47: : 5it [00:06,  1.20s/it]
# [I 2023-06-03 16:40:48,068] Trial 46 finished with value: 0.23220955125060444 and parameters: {'lambda_l1': 1.0089391805943699e-08, 'lambda_l2': 2.096008494433231e-06, 'num_leaves': 205, 'feature_fraction': 0.7978120451035774, 'bagging_fraction': 0.7436674187967309, 'min_child_samples': 31}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 48: : 5it [00:02,  1.69it/s]
# [I 2023-06-03 16:40:51,097] Trial 47 finished with value: 0.23688675286133748 and parameters: {'lambda_l1': 8.237149030367082e-07, 'lambda_l2': 0.00047006945144570036, 'num_leaves': 12, 'feature_fraction': 0.6770589630086403, 'bagging_fraction': 0.9946836032432123, 'min_child_samples': 48}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 49: : 5it [00:03,  1.49it/s]
# [I 2023-06-03 16:40:54,497] Trial 48 finished with value: 0.2300663563606628 and parameters: {'lambda_l1': 4.6273257778309953e-07, 'lambda_l2': 8.634224661834644e-05, 'num_leaves': 37, 'feature_fraction': 0.62323114241602, 'bagging_fraction': 0.8834634697196169, 'min_child_samples': 56}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 50: : 5it [00:03,  1.39it/s]
# [I 2023-06-03 16:40:58,142] Trial 49 finished with value: 0.23388019054619522 and parameters: {'lambda_l1': 7.164305897118675e-08, 'lambda_l2': 4.850390179116595e-07, 'num_leaves': 57, 'feature_fraction': 0.48996795005469834, 'bagging_fraction': 0.8454534229740057, 'min_child_samples': 41}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 51: : 5it [00:03,  1.26it/s]
# [I 2023-06-03 16:41:02,162] Trial 50 finished with value: 0.2379049267511042 and parameters: {'lambda_l1': 1.7914407341341056e-07, 'lambda_l2': 8.742213001798249e-06, 'num_leaves': 12, 'feature_fraction': 0.5897752609605862, 'bagging_fraction': 0.7912721480566443, 'min_child_samples': 26}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 52: : 5it [00:03,  1.52it/s]
# [I 2023-06-03 16:41:05,498] Trial 51 finished with value: 0.22260233767940293 and parameters: {'lambda_l1': 1.1619449682153759e-07, 'lambda_l2': 6.213825472704611e-06, 'num_leaves': 3, 'feature_fraction': 0.5304358470915829, 'bagging_fraction': 0.8946326367300332, 'min_child_samples': 36}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 53: : 5it [00:03,  1.44it/s]
# [I 2023-06-03 16:41:09,013] Trial 52 finished with value: 0.2317936337932684 and parameters: {'lambda_l1': 1.0856509223556163e-06, 'lambda_l2': 4.241805689699225e-06, 'num_leaves': 24, 'feature_fraction': 0.531769883141832, 'bagging_fraction': 0.8876339433225888, 'min_child_samples': 36}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 54: : 5it [00:04,  1.19it/s]
# [I 2023-06-03 16:41:13,255] Trial 53 finished with value: 0.23324654274393036 and parameters: {'lambda_l1': 3.987680198503796e-08, 'lambda_l2': 3.183524906088212e-05, 'num_leaves': 11, 'feature_fraction': 0.576799306517568, 'bagging_fraction': 0.9318957920854816, 'min_child_samples': 29}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 55: : 5it [00:03,  1.58it/s]
# [I 2023-06-03 16:41:16,499] Trial 54 finished with value: 0.23151160611608193 and parameters: {'lambda_l1': 1.3892139662563615e-07, 'lambda_l2': 1.3752374560134404e-05, 'num_leaves': 41, 'feature_fraction': 0.6129280436637415, 'bagging_fraction': 0.8368274779777441, 'min_child_samples': 44}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 56: : 5it [00:04,  1.19it/s]
# [I 2023-06-03 16:41:20,752] Trial 55 finished with value: 0.2646196587678239 and parameters: {'lambda_l1': 4.3207872995951197e-07, 'lambda_l2': 1.1216456358781238e-06, 'num_leaves': 2, 'feature_fraction': 0.4819578198690067, 'bagging_fraction': 0.8958781703205161, 'min_child_samples': 33}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 57: : 5it [00:04,  1.19it/s]
# [I 2023-06-03 16:41:25,012] Trial 56 finished with value: 0.25875471567474717 and parameters: {'lambda_l1': 1.990805171172737e-06, 'lambda_l2': 0.000270376063859044, 'num_leaves': 26, 'feature_fraction': 0.7007586207784069, 'bagging_fraction': 0.9574263015792989, 'min_child_samples': 21}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 58: : 5it [00:03,  1.39it/s]
# [I 2023-06-03 16:41:28,664] Trial 57 finished with value: 0.2255032002004606 and parameters: {'lambda_l1': 1.7123887191624133e-08, 'lambda_l2': 2.081140186073455e-06, 'num_leaves': 11, 'feature_fraction': 0.6626534998056162, 'bagging_fraction': 0.8122605672322268, 'min_child_samples': 54}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 59: : 5it [00:03,  1.58it/s]
# [I 2023-06-03 16:41:31,897] Trial 58 finished with value: 0.22860108162014686 and parameters: {'lambda_l1': 3.6562945305899274e-06, 'lambda_l2': 2.1510608533515234e-05, 'num_leaves': 245, 'feature_fraction': 0.5513482308832239, 'bagging_fraction': 0.9300720899527497, 'min_child_samples': 40}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 60: : 5it [00:04,  1.01it/s]
# [I 2023-06-03 16:41:36,890] Trial 59 finished with value: 0.29756912892141657 and parameters: {'lambda_l1': 4.091688597776429e-08, 'lambda_l2': 0.0008933031383142682, 'num_leaves': 37, 'feature_fraction': 0.74558468607191, 'bagging_fraction': 0.8657615575374593, 'min_child_samples': 12}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 61: : 5it [00:04,  1.07it/s]
# [I 2023-06-03 16:41:41,628] Trial 60 finished with value: 0.24543461511388429 and parameters: {'lambda_l1': 7.872622862592187e-07, 'lambda_l2': 2.3411998801189284e-07, 'num_leaves': 19, 'feature_fraction': 0.7053627802646403, 'bagging_fraction': 0.7802568433560944, 'min_child_samples': 24}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 62: : 5it [00:05,  1.07s/it]
# [I 2023-06-03 16:41:47,013] Trial 61 finished with value: 0.2673871372664284 and parameters: {'lambda_l1': 1.3593873280083356e-07, 'lambda_l2': 6.695048949288477e-06, 'num_leaves': 2, 'feature_fraction': 0.5451638490876949, 'bagging_fraction': 0.8904000205476171, 'min_child_samples': 35}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 63: : 5it [00:02,  1.68it/s]
# [I 2023-06-03 16:41:50,049] Trial 62 finished with value: 0.22239408222460239 and parameters: {'lambda_l1': 6.689645204454635e-08, 'lambda_l2': 1.148203580043345e-05, 'num_leaves': 8, 'feature_fraction': 0.5687500054206214, 'bagging_fraction': 0.8414152158688891, 'min_child_samples': 38}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 64: : 5it [00:03,  1.37it/s]
# [I 2023-06-03 16:41:53,744] Trial 63 finished with value: 0.23491323934990715 and parameters: {'lambda_l1': 2.005572049252489e-08, 'lambda_l2': 1.3345389515444469e-05, 'num_leaves': 29, 'feature_fraction': 0.6519318375123593, 'bagging_fraction': 0.823090303442981, 'min_child_samples': 43}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 65: : 5it [00:03,  1.54it/s]
# [I 2023-06-03 16:41:57,056] Trial 64 finished with value: 0.23144435065390917 and parameters: {'lambda_l1': 2.508310415957284e-07, 'lambda_l2': 9.128354075288891e-07, 'num_leaves': 10, 'feature_fraction': 0.5926574897686243, 'bagging_fraction': 0.8577955019730026, 'min_child_samples': 30}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 66: : 5it [00:02,  1.83it/s]
# [I 2023-06-03 16:41:59,842] Trial 65 finished with value: 0.232101173261754 and parameters: {'lambda_l1': 5.617126211574768e-08, 'lambda_l2': 3.3238259288835382e-06, 'num_leaves': 17, 'feature_fraction': 0.6327141870041254, 'bagging_fraction': 0.725392338931289, 'min_child_samples': 49}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 67: : 5it [00:04,  1.01it/s]
# [I 2023-06-03 16:42:04,870] Trial 66 finished with value: 0.23008567841260258 and parameters: {'lambda_l1': 4.81184820488029e-07, 'lambda_l2': 6.331172941790001e-05, 'num_leaves': 35, 'feature_fraction': 0.5803523838061491, 'bagging_fraction': 0.9091166885360593, 'min_child_samples': 27}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 68: : 5it [00:03,  1.37it/s]
# [I 2023-06-03 16:42:08,577] Trial 67 finished with value: 0.2387884447000151 and parameters: {'lambda_l1': 1.1863854130490158e-07, 'lambda_l2': 3.8729808459401206e-05, 'num_leaves': 8, 'feature_fraction': 0.6681797826319739, 'bagging_fraction': 0.7677421652922342, 'min_child_samples': 98}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 69: : 5it [00:03,  1.55it/s]
# [I 2023-06-03 16:42:11,866] Trial 68 finished with value: 0.2301841812792788 and parameters: {'lambda_l1': 2.531872410930262e-08, 'lambda_l2': 5.56521093075928e-06, 'num_leaves': 24, 'feature_fraction': 0.6152312364414849, 'bagging_fraction': 0.8394906848807734, 'min_child_samples': 37}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 70: : 5it [00:03,  1.41it/s]
# [I 2023-06-03 16:42:15,462] Trial 69 finished with value: 0.23651120187415264 and parameters: {'lambda_l1': 2.263951579253259e-07, 'lambda_l2': 2.493429394843834e-06, 'num_leaves': 51, 'feature_fraction': 0.5079841045422618, 'bagging_fraction': 0.805646792321985, 'min_child_samples': 33}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 71: : 5it [00:02,  1.68it/s]
# [I 2023-06-03 16:42:18,481] Trial 70 finished with value: 0.2277015344447264 and parameters: {'lambda_l1': 8.299272384345544e-06, 'lambda_l2': 1.337870435034336e-05, 'num_leaves': 68, 'feature_fraction': 0.4620872670523727, 'bagging_fraction': 0.9726855934987286, 'min_child_samples': 45}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 72: : 5it [00:03,  1.57it/s]
# [I 2023-06-03 16:42:21,729] Trial 71 finished with value: 0.2335185351912151 and parameters: {'lambda_l1': 8.559372787928184e-08, 'lambda_l2': 7.862368159979869e-06, 'num_leaves': 18, 'feature_fraction': 0.5603847060089346, 'bagging_fraction': 0.9267742725210583, 'min_child_samples': 40}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 73: : 5it [00:03,  1.50it/s]
# [I 2023-06-03 16:42:25,125] Trial 72 finished with value: 0.21507442321759757 and parameters: {'lambda_l1': 9.588039217781559e-08, 'lambda_l2': 1.2645117932244597e-06, 'num_leaves': 6, 'feature_fraction': 0.5282487668882399, 'bagging_fraction': 0.8716658324849118, 'min_child_samples': 36}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 74: : 5it [00:03,  1.66it/s]
# [I 2023-06-03 16:42:28,192] Trial 73 finished with value: 0.22355777678102115 and parameters: {'lambda_l1': 3.180783351917216e-07, 'lambda_l2': 1.3115743595736335e-06, 'num_leaves': 8, 'feature_fraction': 0.5331180339813505, 'bagging_fraction': 0.8599412524793417, 'min_child_samples': 34}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 75: : 5it [00:04,  1.05it/s]
# [I 2023-06-03 16:42:33,030] Trial 74 finished with value: 0.25046372107588966 and parameters: {'lambda_l1': 8.304641890013686e-07, 'lambda_l2': 8.029737497592774e-07, 'num_leaves': 128, 'feature_fraction': 0.515753328716287, 'bagging_fraction': 0.8633094258204801, 'min_child_samples': 18}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 76: : 5it [00:04,  1.13it/s]
# [I 2023-06-03 16:42:37,491] Trial 75 finished with value: 0.22824027130129715 and parameters: {'lambda_l1': 3.3270837629216756e-07, 'lambda_l2': 5.97049163538172e-07, 'num_leaves': 17, 'feature_fraction': 0.5246368786354515, 'bagging_fraction': 0.8246887153780188, 'min_child_samples': 31}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 77: : 5it [00:04,  1.20it/s]
# [I 2023-06-03 16:42:41,713] Trial 76 finished with value: 0.2419476200170993 and parameters: {'lambda_l1': 3.1423771147560955e-06, 'lambda_l2': 1.4846617111492665e-06, 'num_leaves': 26, 'feature_fraction': 0.4477076536750675, 'bagging_fraction': 0.9473043245838537, 'min_child_samples': 23}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 78: : 5it [00:03,  1.41it/s]
# [I 2023-06-03 16:42:45,325] Trial 77 finished with value: 0.22709839998996517 and parameters: {'lambda_l1': 1.4775782758966003e-07, 'lambda_l2': 2.950079780613193e-06, 'num_leaves': 146, 'feature_fraction': 0.5699330777406056, 'bagging_fraction': 0.8764390809966264, 'min_child_samples': 34}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 79: : 5it [00:03,  1.46it/s]
# [I 2023-06-03 16:42:48,794] Trial 78 finished with value: 0.22646437307299205 and parameters: {'lambda_l1': 1.4248366015273155e-06, 'lambda_l2': 2.52107946244902e-07, 'num_leaves': 172, 'feature_fraction': 0.5372382967279905, 'bagging_fraction': 0.8502222322059205, 'min_child_samples': 37}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 80: : 5it [00:03,  1.41it/s]
# [I 2023-06-03 16:42:52,402] Trial 79 finished with value: 0.23898118678249897 and parameters: {'lambda_l1': 4.580664112858936e-08, 'lambda_l2': 1.628512203895117e-06, 'num_leaves': 7, 'feature_fraction': 0.6034154024179971, 'bagging_fraction': 0.7521850522610674, 'min_child_samples': 88}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 81: : 5it [00:03,  1.65it/s]
# [I 2023-06-03 16:42:55,488] Trial 80 finished with value: 0.23355338137701348 and parameters: {'lambda_l1': 6.263523862421452e-07, 'lambda_l2': 4.009066920091348e-06, 'num_leaves': 39, 'feature_fraction': 0.4961370852031466, 'bagging_fraction': 0.7996987358644999, 'min_child_samples': 39}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 82: : 5it [00:03,  1.40it/s]
# [I 2023-06-03 16:42:59,124] Trial 81 finished with value: 0.22194053274652603 and parameters: {'lambda_l1': 6.281213429834879e-08, 'lambda_l2': 2.3527628312412336e-05, 'num_leaves': 8, 'feature_fraction': 0.7042337544196053, 'bagging_fraction': 0.9026686789724097, 'min_child_samples': 27}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 83: : 5it [00:04,  1.23it/s]
# [I 2023-06-03 16:43:03,257] Trial 82 finished with value: 0.2341374440444596 and parameters: {'lambda_l1': 1.4096264689201565e-08, 'lambda_l2': 1.2422637599207499e-06, 'num_leaves': 15, 'feature_fraction': 0.6553397529830407, 'bagging_fraction': 0.9018872295416277, 'min_child_samples': 30}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 84: : 5it [00:03,  1.57it/s]
# [I 2023-06-03 16:43:06,511] Trial 83 finished with value: 0.21352937764132843 and parameters: {'lambda_l1': 3.44500460128887e-08, 'lambda_l2': 2.78788762116586e-05, 'num_leaves': 6, 'feature_fraction': 0.6316772856428078, 'bagging_fraction': 0.9144603446326857, 'min_child_samples': 28}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 85: : 5it [00:04,  1.24it/s]
# [I 2023-06-03 16:43:10,610] Trial 84 finished with value: 0.23722955779161897 and parameters: {'lambda_l1': 2.5190649749672175e-08, 'lambda_l2': 2.442874956758495e-05, 'num_leaves': 31, 'feature_fraction': 0.6384807306511862, 'bagging_fraction': 0.9773182793057376, 'min_child_samples': 27}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 86: : 5it [00:05,  1.01s/it]
# [I 2023-06-03 16:43:15,699] Trial 85 finished with value: 0.240865327254274 and parameters: {'lambda_l1': 1.0778125355255456e-08, 'lambda_l2': 9.866610487942932e-06, 'num_leaves': 106, 'feature_fraction': 0.6819970852419515, 'bagging_fraction': 0.9152598384616774, 'min_child_samples': 25}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 87: : 5it [00:04,  1.04it/s]
# [I 2023-06-03 16:43:20,569] Trial 86 finished with value: 0.27050320809650463 and parameters: {'lambda_l1': 8.218825806464766e-08, 'lambda_l2': 1.735273366767263e-05, 'num_leaves': 2, 'feature_fraction': 0.7163169507698715, 'bagging_fraction': 0.9381372856499667, 'min_child_samples': 22}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 88: : 5it [01:29, 17.93s/it]
# [I 2023-06-03 16:44:50,270] Trial 87 finished with value: 0.2623467172813875 and parameters: {'lambda_l1': 3.383040879743464e-08, 'lambda_l2': 5.28079332692884e-06, 'num_leaves': 21, 'feature_fraction': 0.6193325794438557, 'bagging_fraction': 0.999399566120725, 'min_child_samples': 16}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 89: : 5it [00:05,  1.06s/it]
# [I 2023-06-03 16:44:55,675] Trial 88 finished with value: 0.23413796908507875 and parameters: {'lambda_l1': 1.947453022457475e-07, 'lambda_l2': 3.7857135048357256e-05, 'num_leaves': 15, 'feature_fraction': 0.5681761376496718, 'bagging_fraction': 0.87772700190883, 'min_child_samples': 28}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 90: : 5it [00:02,  1.76it/s]
# [I 2023-06-03 16:44:58,580] Trial 89 finished with value: 0.22690711193363838 and parameters: {'lambda_l1': 5.711729721504358e-08, 'lambda_l2': 1.249918127513252e-05, 'num_leaves': 7, 'feature_fraction': 0.6989805080423962, 'bagging_fraction': 0.9554398641955546, 'min_child_samples': 42}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 91: : 5it [00:04,  1.19it/s]
# [I 2023-06-03 16:45:02,818] Trial 90 finished with value: 0.2305435151672949 and parameters: {'lambda_l1': 1.2704489763554643e-07, 'lambda_l2': 5.2973600227735955e-06, 'num_leaves': 27, 'feature_fraction': 0.6014924416627144, 'bagging_fraction': 0.8361786386662257, 'min_child_samples': 33}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 92: : 5it [00:02,  1.67it/s]
# [I 2023-06-03 16:45:05,858] Trial 91 finished with value: 0.23242328510097 and parameters: {'lambda_l1': 2.3497960769891942e-07, 'lambda_l2': 2.5749003605511492e-06, 'num_leaves': 10, 'feature_fraction': 0.5397096812355665, 'bagging_fraction': 0.8631267350575138, 'min_child_samples': 35}. Best is trial 18 with value: 0.21299345281896337.
# [train] trials 93: : 5it [00:03,  1.65it/s]
# [I 2023-06-03 16:45:08,945] Trial 92 finished with value: 0.2123926514129733 and parameters: {'lambda_l1': 3.9679492838164295e-07, 'lambda_l2': 6.757138144718837e-07, 'num_leaves': 7, 'feature_fraction': 0.6627683984494798, 'bagging_fraction': 0.9135956967880636, 'min_child_samples': 32}. Best is trial 92 with value: 0.2123926514129733.
# [train] trials 94: : 5it [00:03,  1.41it/s]
# [I 2023-06-03 16:45:12,536] Trial 93 finished with value: 0.23144578048035233 and parameters: {'lambda_l1': 9.890354144102226e-08, 'lambda_l2': 5.500397318199656e-07, 'num_leaves': 21, 'feature_fraction': 0.6707976501945869, 'bagging_fraction': 0.9165950932031024, 'min_child_samples': 32}. Best is trial 92 with value: 0.2123926514129733.
# [train] trials 95: : 5it [00:04,  1.09it/s]
# [I 2023-06-03 16:45:17,179] Trial 94 finished with value: 0.26378381827675834 and parameters: {'lambda_l1': 4.878984713941203e-08, 'lambda_l2': 3.098969084225069e-05, 'num_leaves': 2, 'feature_fraction': 0.6359566577002023, 'bagging_fraction': 0.9044201033475665, 'min_child_samples': 38}. Best is trial 92 with value: 0.2123926514129733.
# [train] trials 96: : 5it [00:03,  1.49it/s]
# [I 2023-06-03 16:45:20,623] Trial 95 finished with value: 0.24263169629028244 and parameters: {'lambda_l1': 2.8463131492480384e-08, 'lambda_l2': 9.705092354259722e-06, 'num_leaves': 14, 'feature_fraction': 0.7228230141816837, 'bagging_fraction': 0.8818969478752431, 'min_child_samples': 28}. Best is trial 92 with value: 0.2123926514129733.
# [train] trials 97: : 5it [00:03,  1.51it/s]
# [I 2023-06-03 16:45:23,991] Trial 96 finished with value: 0.22705589408585877 and parameters: {'lambda_l1': 3.734164169502808e-07, 'lambda_l2': 1.969938070700246e-05, 'num_leaves': 8, 'feature_fraction': 0.7415510085087494, 'bagging_fraction': 0.9412772342613909, 'min_child_samples': 25}. Best is trial 92 with value: 0.2123926514129733.
# [train] trials 98: : 5it [00:03,  1.50it/s]
# [I 2023-06-03 16:45:27,370] Trial 97 finished with value: 0.2257635416069895 and parameters: {'lambda_l1': 7.066562200403116e-08, 'lambda_l2': 2.2636058052052594e-06, 'num_leaves': 33, 'feature_fraction': 0.6566952783890507, 'bagging_fraction': 0.8949527610345949, 'min_child_samples': 40}. Best is trial 92 with value: 0.2123926514129733.
# [train] trials 99: : 5it [00:03,  1.44it/s]
# [I 2023-06-03 16:45:30,892] Trial 98 finished with value: 0.226458807900963 and parameters: {'lambda_l1': 1.6140429962306642e-08, 'lambda_l2': 4.241855215414328e-07, 'num_leaves': 15, 'feature_fraction': 0.693775479717719, 'bagging_fraction': 0.9214348667616341, 'min_child_samples': 36}. Best is trial 92 with value: 0.2123926514129733.
# [train] trials 100: : 5it [00:03,  1.27it/s]
# [I 2023-06-03 16:45:34,902] Trial 99 finished with value: 0.22895377419260532 and parameters: {'lambda_l1': 1.0779707401334257e-06, 'lambda_l2': 8.157776025043797e-07, 'num_leaves': 22, 'feature_fraction': 0.6252510342197767, 'bagging_fraction': 0.8259791567870678, 'min_child_samples': 31}. Best is trial 92 with value: 0.2123926514129733.

# %%
best_params = study.best_trial.params
best_value = study.best_value
print("best_param: {}\n\nbest_value: {}".format(best_params, best_value))
# Out:
# best_param: {'lambda_l1': 3.9679492838164295e-07, 'lambda_l2': 6.757138144718837e-07, 'num_leaves': 7, 'feature_fraction': 0.6627683984494798, 'bagging_fraction': 0.9135956967880636, 'min_child_samples': 32}
#
# best_value: 0.2123926514129733

# %%
"""
# best_paramsには固定値が保存されないので改めて設定
best_params["boosting_type"] = CFG.boosting_type
best_params["device_type"] = CFG.device_type
best_params["seed"] = CFG.seed
best_params["n_jobs"] = -1
best_params["is_unbalance"] = True
best_params["objective"] = "binary"
best_params["learning_rate"] = 0.005
best_params["metric"] = "binary_logloss"
best_params["verbosity"] = -1

# 設定したハイパーパラメータを基にモデルを作成
model = lgb.LGBMClassifier(**best_params)
# 学習
model.fit(train_df[features], train_df[CFG.target_col])
"""
# Out:
# '\n# best_paramsには固定値が保存されないので改めて設定\nbest_params["boosting_type"] = CFG.boosting_type\nbest_params["device_type"] = CFG.device_type\nbest_params["seed"] = CFG.seed\nbest_params["n_jobs"] = -1\nbest_params["is_unbalance"] = True\nbest_params["objective"] = "binary"\nbest_params["learning_rate"] = 0.005\nbest_params["metric"] = "binary_logloss"\nbest_params["verbosity"] = -1\n\n# 設定したハイパーパラメータを基にモデルを作成\nmodel = lgb.LGBMClassifier(**best_params)\n# 学習\nmodel.fit(train_df[features], train_df[CFG.target_col])\n'

# %%
"""
# 予測
prediction = model.predict_proba(test_df.drop(["Id", "Class"], axis=1))
# 提出用に値を変換
prediction = max(min(prediction, 1-10**(-15)), 10**(-15))
submission = pd.DataFrame(columns = submission_df.columns)
submission['Id'] = test_df['Id']
submission[['class_0','class_1']] = prediction
submission.to_csv('submission.csv',index=False)
submission
"""
# Out:
# '\n# 予測\nprediction = model.predict_proba(test_df.drop(["Id", "Class"], axis=1))\n# 提出用に値を変換\nprediction = max(min(prediction, 1-10**(-15)), 10**(-15))\nsubmission = pd.DataFrame(columns = submission_df.columns)\nsubmission[\'Id\'] = test_df[\'Id\']\nsubmission[[\'class_0\',\'class_1\']] = prediction\nsubmission.to_csv(\'submission.csv\',index=False)\nsubmission\n'
